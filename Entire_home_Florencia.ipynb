# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv('Florencia_limpio.csv')
df.head(5)
# Out:
#    Unnamed: 0                                      name  \
# 0           0          A Residenza Martin  Classic room
# 1           1        Welcome at Corte Verde in Florence
# 2           2       Charming Gem - Oltrarno City centre
# 3           3            Central Double Shared Bathroom
# 4           4  Florence Central Double Private Bathroom
#
#                                          description  \
# 0  Nice, private and quiet double room, classic s...
# 1  Apartment at a 30 minute walk from Ponte Vecch...
# 2                                                  .
# 3  Double (or Twin) Room Shared Bathroom: comfort...
# 4  Double room private bathroom: comfortable, lar...
#
#                                neighborhood_overview     host_name  \
# 0                        No se proporcionan detalles  Officina 360
# 1                        No se proporcionan detalles         Lucia
# 2                        No se proporcionan detalles        Cesare
# ...

# %%
#eliminamos la columna unnamed 
df= df.drop(['Unnamed: 0'], axis=1)
df.head(5)
# Out:
#                                        name  \
# 0          A Residenza Martin  Classic room
# 1        Welcome at Corte Verde in Florence
# 2       Charming Gem - Oltrarno City centre
# 3            Central Double Shared Bathroom
# 4  Florence Central Double Private Bathroom
#
#                                          description  \
# 0  Nice, private and quiet double room, classic s...
# 1  Apartment at a 30 minute walk from Ponte Vecch...
# 2                                                  .
# 3  Double (or Twin) Room Shared Bathroom: comfort...
# 4  Double room private bathroom: comfortable, lar...
#
#                                neighborhood_overview     host_name  \
# 0                        No se proporcionan detalles  Officina 360
# 1                        No se proporcionan detalles         Lucia
# 2                        No se proporcionan detalles        Cesare
# 3  San Lorenzo Church, the market and Cappelle Me...       Lorenzo
# ...

# %%
f1=df.iloc[ :  , [7,8,9,12,13,19,23,24,27,39] ]
f1
# Out:
#       host_acceptance_rate host_is_superhost host_identity_verified  \
# 0                     100%                 f                      t
# 1                      25%                 f                      t
# 2                      65%                 f                      t
# 3                      71%                 f                      t
# 4                      71%                 f                      t
# ...                    ...               ...                    ...
# 12717                 100%                 f                      t
# 12718                 100%                 f                      t
# 12719                  100                 f                      t
# 12720                  97%                 t                      t
# 12721                 100%                 t                      t
#
#                             property_type        room_type instant_bookable  \
# ...

# %%
#convertimos string a tipos numéricos
f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
f1['property_type'] = encoder.fit_transform(f1['property_type'])

f1['host_acceptance_rate'] = f1['host_acceptance_rate'].astype(str).str.rstrip('%')
f1['host_acceptance_rate'] = pd.to_numeric(f1['host_acceptance_rate'], errors='coerce').fillna(0)

f1['room_type'] = f1['room_type'].map({
    'Entire home/apt': 1,
    'Private room': 2,
    'Shared room': 3,
    'Hotel room': 4
})
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_56860\1540311677.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_56860\1540311677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# ...

# %%
#f2 = Entire home/apt
f2= f1[(f1["room_type"] == 1)]
#f3 = Private room
f3= f1[(f1["room_type"] == 2)]
#f4 = Shared room
f4= f1[(f1["room_type"] == 3)]
#f5 = Hotel room
f5= f1[(f1["room_type"] == 4)]

# %%
#imprimimos el scatter plot entre la variable dependiente (price) e indpendiente (room_type)
#para observar el comportamiento en su dispersión
from turtle import color

sns.scatterplot(x='room_type',y='price', color="blue", data=f2)
#sns.scatterplot(x='property_type',y='price', color="red", data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_acceptance_rate',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_is_superhost',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_identity_verified',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='instant_bookable',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='bathrooms',y='accommodates', color="blue", data=f2)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
from turtle import color

sns.scatterplot(x='review_scores_cleanliness',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
Vars_Indep1= f2 [['room_type']]
Vars_Dep1= f2 ['price']

# %%
Vars_Indep2= f2 [['host_acceptance_rate']]
Vars_Dep2= f2 ['price']

# %%
Vars_Indep3= f2 [['host_is_superhost']]
Vars_Dep3= f2 ['price']

# %%
Vars_Indep4= f2 [['host_identity_verified']]
Vars_Dep4= f2 ['price']

# %%
Vars_Indep5= f2 [['instant_bookable']]
Vars_Dep5= f2 ['price']

# %%
Vars_Indep6= f2 [['bathrooms']]
Vars_Dep6= f2 ['accommodates']

# %%
Vars_Indep7= f2 [['review_scores_cleanliness']]
Vars_Dep7= f2 ['price']

# %%
Vars_Indep8= f2 [['property_type']]
Vars_Dep8= f2 ['price']

# %%
from sklearn.linear_model import LinearRegression
model_1= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_2= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_3= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_4= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_5= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_6= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_7= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_8= LinearRegression()

# %%
type(model_1)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_2)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_3)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_4)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_5)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_6)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_7)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_8)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model_1.fit(X=Vars_Indep1, y=Vars_Dep1)
# Out:
# LinearRegression()

# %%
model_2.fit(X=Vars_Indep2, y=Vars_Dep2)
# Out:
# LinearRegression()

# %%
model_3.fit(X=Vars_Indep3, y=Vars_Dep3)
# Out:
# LinearRegression()

# %%
model_4.fit(X=Vars_Indep4, y=Vars_Dep4)
# Out:
# LinearRegression()

# %%
model_5.fit(X=Vars_Indep5, y=Vars_Dep5)
# Out:
# LinearRegression()

# %%
model_6.fit(X=Vars_Indep6, y=Vars_Dep6)
# Out:
# LinearRegression()

# %%
model_7.fit(X=Vars_Indep7, y=Vars_Dep7)
# Out:
# LinearRegression()

# %%
model_8.fit(X=Vars_Indep8, y=Vars_Dep8)
# Out:
# LinearRegression()

# %%
model_1.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['room_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(181.11272004542874)}

# %%
model_2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.4505093]),
#  'rank_': 1,
#  'singular_': array([1783.91958649]),
#  'intercept_': np.float64(138.51038396004287)}

# %%
model_3.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.392508]),
#  'rank_': 1,
#  'singular_': array([51.09761084]),
#  'intercept_': np.float64(180.93756622799523)}

# %%
model_4.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_identity_verified'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-4.63193088]),
#  'rank_': 1,
#  'singular_': array([18.44649911]),
#  'intercept_': np.float64(185.5903409090907)}

# %%
model_5.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['instant_bookable'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([30.47372049]),
#  'rank_': 1,
#  'singular_': array([49.68658919]),
#  'intercept_': np.float64(161.97939979654188)}

# %%
model_6.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['bathrooms'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([1.37946649]),
#  'rank_': 1,
#  'singular_': array([40.98694405]),
#  'intercept_': np.float64(2.1242776176885476)}

# %%
model_7.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([31.58986083]),
#  'rank_': 1,
#  'singular_': array([16.50443816]),
#  'intercept_': np.float64(27.808315361755803)}

# %%
model_8.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.26128252]),
#  'rank_': 1,
#  'singular_': array([421.78086979]),
#  'intercept_': np.float64(177.43381959785873)}

# %%
y_pred_1= model_1.predict(X=f2[['room_type']])
y_pred_1
# Out:
# array([181.11272005, 181.11272005, 181.11272005, ..., 181.11272005,
#        181.11272005, 181.11272005], shape=(10566,))

# %%
y_pred_2= model_2.predict(X=f2[['host_acceptance_rate']])
y_pred_2
# Out:
# array([149.77311658, 167.79348877, 183.56131444, ..., 183.56131444,
#        182.20978652, 183.56131444], shape=(10566,))

# %%
y_pred_3= model_3.predict(X=f2[['host_is_superhost']])
y_pred_3
# Out:
# array([180.93756623, 180.93756623, 180.93756623, ..., 180.93756623,
#        181.33007423, 181.33007423], shape=(10566,))

# %%
y_pred_4= model_4.predict(X=f2[['host_identity_verified']])
y_pred_4
# Out:
# array([180.95841003, 180.95841003, 180.95841003, ..., 180.95841003,
#        180.95841003, 180.95841003], shape=(10566,))

# %%
y_pred_5= model_5.predict(X=f2[['instant_bookable']])
y_pred_5
# Out:
# array([161.9793998 , 161.9793998 , 161.9793998 , ..., 161.9793998 ,
#        161.9793998 , 192.45312029], shape=(10566,))

# %%
y_pred_6= model_6.predict(X=f2[['bathrooms']])
y_pred_6
# Out:
# array([3.5037441 , 4.88321059, 3.5037441 , ..., 3.5037441 , 3.5037441 ,
#        3.5037441 ], shape=(10566,))

# %%
y_pred_7= model_7.predict(X=f2[['review_scores_cleanliness']])
y_pred_7
# Out:
# array([181.96683621, 181.01914039, 167.75139884, ..., 185.75761951,
#        185.75761951, 185.75761951], shape=(10566,))

# %%
y_pred_8= model_8.predict(X=f2[['property_type']])
y_pred_8
# Out:
# array([181.61433996, 179.52407978, 181.61433996, ..., 181.61433996,
#        181.61433996, 181.61433996], shape=(10566,))

# %%
f2_c = f2.copy()

# %%
f2.insert(0, 'Pred_room', y_pred_1)
f2
# Out:
#        Pred_room  host_acceptance_rate  host_is_superhost  \
# 1      181.11272                    25                  0
# 2      181.11272                    65                  0
# 5      181.11272                   100                  0
# 6      181.11272                    99                  0
# 7      181.11272                   100                  1
# ...          ...                   ...                ...
# 12717  181.11272                   100                  0
# 12718  181.11272                   100                  0
# 12719  181.11272                   100                  0
# 12720  181.11272                    97                  1
# 12721  181.11272                   100                  1
#
#        host_identity_verified  property_type  room_type  instant_bookable  \
# 1                           1             16          1                 0
# 2                           1              8          1                 0
# ...

# %%
f2_c.insert(0, 'Pred_acceptance', y_pred_2)
f2_c.insert(0, 'Pred_superhost', y_pred_3)
f2_c.insert(0, 'Pred_identity', y_pred_4)
f2_c.insert(0, 'Pred_bookable', y_pred_5)
f2_c.insert(0, 'Pred_bathrooms', y_pred_6)
f2_c.insert(0, 'Pred_cleanliness', y_pred_7)
f2_c.insert(0, 'Pred_property', y_pred_8)

# %%
sns.scatterplot(x='room_type', y='price', color="blue", data = f2)
sns.scatterplot(x='room_type', y='Pred_room', color="red", data = f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.scatterplot(x='host_acceptance_rate', y='price', color="blue", data = f2_c)
sns.scatterplot(x='host_acceptance_rate', y='Pred_acceptance', color="red", data = f2_c)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
sns.scatterplot(x='host_is_superhost', y='price', color="blue", data = f2_c)
sns.scatterplot(x='host_is_superhost', y='Pred_superhost', color="red", data = f2_c)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
sns.scatterplot(x='host_identity_verified', y='price', color="blue", data = f2_c)
sns.scatterplot(x='host_identity_verified', y='Pred_identity', color="red", data = f2_c)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
sns.scatterplot(x='instant_bookable', y='price', color="blue", data = f2_c)
sns.scatterplot(x='instant_bookable', y='Pred_bookable', color="red", data = f2_c)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
sns.scatterplot(x='bathrooms', y='accommodates', color="blue", data = f2_c)
sns.scatterplot(x='bathrooms', y='Pred_bathrooms', color="red", data = f2_c)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
sns.scatterplot(x='review_scores_cleanliness', y='price', color="blue", data = f2_c)
sns.scatterplot(x='review_scores_cleanliness', y='Pred_cleanliness', color="red", data = f2_c)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
sns.scatterplot(x='property_type', y='price', color="blue", data = f2_c)
sns.scatterplot(x='property_type', y='Pred_property', color="red", data = f2_c)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
coef_Deter_1= model_1.score(X=Vars_Indep1, y=Vars_Dep1)
coef_Deter_1
# Out:
# 0.0

# %%
coef_Deter_2= model_2.score(X=Vars_Indep2, y=Vars_Dep2)
coef_Deter_2
# Out:
# 0.008653049012803282

# %%
coef_Deter_3= model_3.score(X=Vars_Indep3, y=Vars_Dep3)
coef_Deter_3
# Out:
# 5.389013939538501e-06

# %%
coef_Deter_4= model_4.score(X=Vars_Indep4, y=Vars_Dep4)
coef_Deter_4
# Out:
# 9.780546827309333e-05

# %%
coef_Deter_5= model_5.score(X=Vars_Indep5, y=Vars_Dep5)
coef_Deter_5
# Out:
# 0.03071428537377896

# %%
coef_Deter_6= model_6.score(X=Vars_Indep6, y=Vars_Dep6)
coef_Deter_6
# Out:
# 0.16401124991948146

# %%
coef_Deter_7= model_7.score(X=Vars_Indep7, y=Vars_Dep7)
coef_Deter_7
# Out:
# 0.003641732150196586

# %%
coef_Deter_8= model_8.score(X=Vars_Indep8, y=Vars_Dep8)
coef_Deter_8
# Out:
# 0.0001627067466642984

# %%
coef_Correl_1= np.sqrt(coef_Deter_1)
coef_Correl_1
# Out:
# np.float64(0.0)

# %%
coef_Correl_2= np.sqrt(coef_Deter_2)
coef_Correl_2
# Out:
# np.float64(0.09302176633886976)

# %%
coef_Correl_3= np.sqrt(coef_Deter_3)
coef_Correl_3
# Out:
# np.float64(0.002321424980381339)

# %%
coef_Correl_4= np.sqrt(coef_Deter_4)
coef_Correl_4
# Out:
# np.float64(0.00988966471995352)

# %%
coef_Correl_5= np.sqrt(coef_Deter_5)
coef_Correl_5
# Out:
# np.float64(0.17525491540547147)

# %%
coef_Correl_6= np.sqrt(coef_Deter_6)
coef_Correl_6
# Out:
# np.float64(0.4049830242361789)

# %%
coef_Correl_7= np.sqrt(coef_Deter_7)
coef_Correl_7
# Out:
# np.float64(0.060346765863603546)

# %%
coef_Correl_8= np.sqrt(coef_Deter_8)
coef_Correl_8
# Out:
# np.float64(0.012755655477642002)

# %%
df6 = f2.groupby(['room_type'])['room_type'].count()
df6
# Out:
# room_type
# 1    10566
# Name: room_type, dtype: int64

# %%
Corr_Factors=f2.corr()
Corr_Factors
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.167648
# host_is_superhost                NaN              0.167648           1.000000
# host_identity_verified           NaN              0.115836           0.084956
# property_type                    NaN             -0.019036          -0.095071
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN              0.338334          -0.074590
# accommodates                     NaN              0.062229          -0.038367
# bathrooms                        NaN              0.019100           0.015981
# price                            NaN              0.093022           0.002321
# review_scores_cleanliness        NaN             -0.049404           0.188801
#
# ...

# %%
Corr_Factors_pred=f2_c.corr()
Corr_Factors_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000         -0.010017        0.008922
# Pred_cleanliness               -0.010017          1.000000        0.025760
# Pred_bathrooms                  0.008922          0.025760        1.000000
# Pred_bookable                   0.073160         -0.119886        0.036771
# Pred_identity                   0.029534          0.026695       -0.013575
# Pred_superhost                 -0.095071          0.188801        0.015981
# Pred_acceptance                -0.019036         -0.049404        0.019100
# host_acceptance_rate           -0.019036         -0.049404        0.019100
# host_is_superhost              -0.095071          0.188801        0.015981
# host_identity_verified         -0.029534         -0.026695        0.013575
# property_type                   1.000000         -0.010017        0.008922
# ...

# %%
Corr_Factors1=abs(Corr_Factors)
Corr_Factors1
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.167648
# host_is_superhost                NaN              0.167648           1.000000
# host_identity_verified           NaN              0.115836           0.084956
# property_type                    NaN              0.019036           0.095071
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN              0.338334           0.074590
# accommodates                     NaN              0.062229           0.038367
# bathrooms                        NaN              0.019100           0.015981
# price                            NaN              0.093022           0.002321
# review_scores_cleanliness        NaN              0.049404           0.188801
#
# ...

# %%
Corr_Factors1_pred=abs(Corr_Factors_pred)
Corr_Factors1_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000          0.010017        0.008922
# Pred_cleanliness                0.010017          1.000000        0.025760
# Pred_bathrooms                  0.008922          0.025760        1.000000
# Pred_bookable                   0.073160          0.119886        0.036771
# Pred_identity                   0.029534          0.026695        0.013575
# Pred_superhost                  0.095071          0.188801        0.015981
# Pred_acceptance                 0.019036          0.049404        0.019100
# host_acceptance_rate            0.019036          0.049404        0.019100
# host_is_superhost               0.095071          0.188801        0.015981
# host_identity_verified          0.029534          0.026695        0.013575
# property_type                   1.000000          0.010017        0.008922
# ...

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1_pred, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >
