# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv('Mexico_limpio.csv')
df.head(5)
# Out:
#    Unnamed: 0                                              name  \
# 0           0                                       Villa Dante
# 1           1                                      Condesa Haus
# 2           2                 2 bedroom apt. deco bldg, Condesa
# 3           3  Beautiful light Studio Coyoacan- full equipped !
# 4           4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview host_name  host_since  \
# 0  Santa Fe Mall, Interloma Park and the Lion Des...      Dici  2010-06-28
# 1                        No se proporcionan detalles  Fernando  2010-08-09
# 2                        No se proporcionan detalles  Nicholas  2011-01-04
# 3  Coyoacan is a beautiful neighborhood famous fo...    Trisha  2010-08-24
# 4  Is located in the best area of Mexico City, Po...    Andrea  2011-04-27
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  a few days or more                 0%                  100
# 1      within an hour               100%                  93%
# 2      within an hour                71%                  57%
# 3  within a few hours               100%                 100%
# 4      within an hour               100%                 100%
#
#   host_is_superhost  ... review_scores_cleanliness review_scores_checkin  \
# 0                 f  ...                      5.00                  5.00
# 1                 t  ...                      4.70                  4.87
# 2                 t  ...                      4.75                  4.94
# 3                 t  ...                      4.96                  4.96
# 4                 t  ...                      5.00                  5.00
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        5.00                   4.80                4.70
# 1                        4.78                   4.98                4.48
# 2                        4.92                   4.98                4.91
# 3                        4.98                   4.96                4.92
# 4                        4.73                   4.91                4.82
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                            1.0                                         1.0
# 1                            8.0                                         4.0
# 2                            2.0                                         2.0
# 3                            3.0                                         2.0
# 4                            3.0                                         3.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          1.0
# 2                                          0.0
# 3                                          1.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              1.70
# 1                                         0.0              0.41
# 2                                         0.0              0.31
# 3                                         0.0              0.83
# 4                                         0.0              0.11
#
# [5 rows x 50 columns]

# %%
#eliminamos la columna unnamed 
df= df.drop(['Unnamed: 0'], axis=1)
df.head(5)
# Out:
#                                                name  \
# 0                                       Villa Dante
# 1                                      Condesa Haus
# 2                 2 bedroom apt. deco bldg, Condesa
# 3  Beautiful light Studio Coyoacan- full equipped !
# 4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview host_name  host_since  \
# 0  Santa Fe Mall, Interloma Park and the Lion Des...      Dici  2010-06-28
# 1                        No se proporcionan detalles  Fernando  2010-08-09
# 2                        No se proporcionan detalles  Nicholas  2011-01-04
# 3  Coyoacan is a beautiful neighborhood famous fo...    Trisha  2010-08-24
# 4  Is located in the best area of Mexico City, Po...    Andrea  2011-04-27
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  a few days or more                 0%                  100
# 1      within an hour               100%                  93%
# 2      within an hour                71%                  57%
# 3  within a few hours               100%                 100%
# 4      within an hour               100%                 100%
#
#   host_is_superhost host_identity_verified  ... review_scores_cleanliness  \
# 0                 f                      t  ...                      5.00
# 1                 t                      t  ...                      4.70
# 2                 t                      t  ...                      4.75
# 3                 t                      t  ...                      4.96
# 4                 t                      t  ...                      5.00
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  5.00                        5.00                   4.80
# 1                  4.87                        4.78                   4.98
# 2                  4.94                        4.92                   4.98
# 3                  4.96                        4.98                   4.96
# 4                  5.00                        4.73                   4.91
#
#   review_scores_value calculated_host_listings_count  \
# 0                4.70                            1.0
# 1                4.48                            8.0
# 2                4.91                            2.0
# 3                4.92                            3.0
# 4                4.82                            3.0
#
#   calculated_host_listings_count_entire_homes  \
# 0                                         1.0
# 1                                         4.0
# 2                                         2.0
# 3                                         2.0
# 4                                         3.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          1.0
# 2                                          0.0
# 3                                          1.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              1.70
# 1                                         0.0              0.41
# 2                                         0.0              0.31
# 3                                         0.0              0.83
# 4                                         0.0              0.11
#
# [5 rows x 49 columns]

# %%
f1=df.iloc[ :  , [7,8,9,12,13,19,23,24,27,39] ]
f1
# Out:
#       host_acceptance_rate host_is_superhost host_identity_verified  \
# 0                      100                 f                      t
# 1                      93%                 t                      t
# 2                      57%                 t                      t
# 3                     100%                 t                      t
# 4                     100%                 t                      t
# ...                    ...               ...                    ...
# 26577                 100%                 t                      t
# 26578                 100%                 f                      t
# 26579                 100%                 f                      t
# 26580                 100%                 f                      t
# 26581                 100%                 t                      t
#
#                     property_type        room_type instant_bookable  \
# 0                    Entire villa  Entire home/apt                f
# 1                     Entire home  Entire home/apt                f
# 2              Entire rental unit  Entire home/apt                f
# 3              Entire rental unit  Entire home/apt                f
# 4                     Entire loft  Entire home/apt                f
# ...                           ...              ...              ...
# 26577  Private room in guesthouse     Private room                t
# 26578               Room in hotel     Private room                t
# 26579               Room in hotel     Private room                t
# 26580               Room in hotel     Private room                t
# 26581          Entire rental unit  Entire home/apt                t
#
#        accommodates  bathrooms   price  review_scores_cleanliness
# 0               2.0        1.0  1093.1                       5.00
# 1               2.9        1.0  1511.6                       4.70
# 2               4.0        1.0  2029.0                       4.75
# 3               2.0        1.0  1140.0                       4.96
# 4               2.0        1.5  1093.1                       5.00
# ...             ...        ...     ...                        ...
# 26577           4.0        1.0   488.0                       5.00
# 26578           2.0        1.0  1093.1                       5.00
# 26579           2.0        1.0  2700.0                       5.00
# 26580           2.0        1.0  2600.0                       5.00
# 26581           2.0        1.0  1353.0                       5.00
#
# [26582 rows x 10 columns]

# %%
#convertimos string a tipos numéricos
f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
f1['property_type'] = encoder.fit_transform(f1['property_type'])

f1['host_acceptance_rate'] = f1['host_acceptance_rate'].astype(str).str.rstrip('%')
f1['host_acceptance_rate'] = pd.to_numeric(f1['host_acceptance_rate'], errors='coerce').fillna(0)

f1['room_type'] = f1['room_type'].map({
    'Entire home/apt': 1,
    'Private room': 2,
    'Shared room': 3,
    'Hotel room': 4
})
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['property_type'] = encoder.fit_transform(f1['property_type'])
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_acceptance_rate'] = f1['host_acceptance_rate'].astype(str).str.rstrip('%')
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_acceptance_rate'] = pd.to_numeric(f1['host_acceptance_rate'], errors='coerce').fillna(0)
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32620\1540311677.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['room_type'] = f1['room_type'].map({

# %%
#f2 = Entire home/apt
f2= f1[(f1["room_type"] == 1)]
#f3 = Private room
f3= f1[(f1["room_type"] == 2)]
#f4 = Shared room
f4= f1[(f1["room_type"] == 3)]
#f5 = Hotel room
f5= f1[(f1["room_type"] == 4)]

# %%
#imprimimos el scatter plot entre la variable dependiente (price) e indpendiente (room_type)
#para observar el comportamiento en su dispersión
from turtle import color

sns.scatterplot(x='room_type',y='price', color="blue", data=f2)
#sns.scatterplot(x='property_type',y='price', color="red", data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_acceptance_rate',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_is_superhost',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_identity_verified',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='instant_bookable',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='bathrooms',y='accommodates', color="blue", data=f2)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
from turtle import color

sns.scatterplot(x='review_scores_cleanliness',y='price', color="blue", data=f2)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
Vars_Indep1= f2 [['room_type']]
Vars_Dep1= f2 ['price']

# %%
Vars_Indep2= f2 [['host_acceptance_rate']]
Vars_Dep2= f2 ['price']

# %%
Vars_Indep3= f2 [['host_is_superhost']]
Vars_Dep3= f2 ['price']

# %%
Vars_Indep4= f2 [['host_identity_verified']]
Vars_Dep4= f2 ['price']

# %%
Vars_Indep5= f2 [['instant_bookable']]
Vars_Dep5= f2 ['price']

# %%
Vars_Indep6= f2 [['bathrooms']]
Vars_Dep6= f2 ['accommodates']

# %%
Vars_Indep7= f2 [['review_scores_cleanliness']]
Vars_Dep7= f2 ['price']

# %%
Vars_Indep8= f2 [['property_type']]
Vars_Dep8= f2 ['price']

# %%
from sklearn.linear_model import LinearRegression
model_1= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_2= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_3= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_4= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_5= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_6= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_7= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_8= LinearRegression()

# %%
type(model_1)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_2)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_3)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_4)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_5)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_6)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_7)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_8)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model_1.fit(X=Vars_Indep1, y=Vars_Dep1)
# Out:
# LinearRegression()

# %%
model_2.fit(X=Vars_Indep2, y=Vars_Dep2)
# Out:
# LinearRegression()

# %%
model_3.fit(X=Vars_Indep3, y=Vars_Dep3)
# Out:
# LinearRegression()

# %%
model_4.fit(X=Vars_Indep4, y=Vars_Dep4)
# Out:
# LinearRegression()

# %%
model_5.fit(X=Vars_Indep5, y=Vars_Dep5)
# Out:
# LinearRegression()

# %%
model_6.fit(X=Vars_Indep6, y=Vars_Dep6)
# Out:
# LinearRegression()

# %%
model_7.fit(X=Vars_Indep7, y=Vars_Dep7)
# Out:
# LinearRegression()

# %%
model_8.fit(X=Vars_Indep8, y=Vars_Dep8)
# Out:
# LinearRegression()

# %%
model_1.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['room_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(1247.1754189944133)}

# %%
model_2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([1.09293349]),
#  'rank_': 1,
#  'singular_': array([2504.00072491]),
#  'intercept_': np.float64(1145.4285545552368)}

# %%
model_3.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([21.00986237]),
#  'rank_': 1,
#  'singular_': array([65.53449846]),
#  'intercept_': np.float64(1237.7516553524804)}

# %%
model_4.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_identity_verified'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-112.80942578]),
#  'rank_': 1,
#  'singular_': array([20.54754994]),
#  'intercept_': np.float64(1357.171593533486)}

# %%
model_5.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['instant_bookable'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([71.48464608]),
#  'rank_': 1,
#  'singular_': array([65.05823086]),
#  'intercept_': np.float64(1217.0755372065255)}

# %%
model_6.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['bathrooms'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.97488088]),
#  'rank_': 1,
#  'singular_': array([78.15957308]),
#  'intercept_': np.float64(2.1063441944025767)}

# %%
model_7.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([381.28956491]),
#  'rank_': 1,
#  'singular_': array([19.28068787]),
#  'intercept_': np.float64(-604.4218714343112)}

# %%
model_8.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-4.56100445]),
#  'rank_': 1,
#  'singular_': array([1056.1511934]),
#  'intercept_': np.float64(1325.0492572068565)}

# %%
y_pred_1= model_1.predict(X=f2[['room_type']])
y_pred_1
# Out:
# array([1247.17541899, 1247.17541899, 1247.17541899, ..., 1247.17541899,
#        1247.17541899, 1247.17541899], shape=(17363,))

# %%
y_pred_2= model_2.predict(X=f2[['host_acceptance_rate']])
y_pred_2
# Out:
# array([1254.72190348, 1247.07136906, 1207.72576344, ..., 1254.72190348,
#        1254.72190348, 1254.72190348], shape=(17363,))

# %%
y_pred_3= model_3.predict(X=f2[['host_is_superhost']])
y_pred_3
# Out:
# array([1237.75165535, 1258.76151772, 1258.76151772, ..., 1237.75165535,
#        1237.75165535, 1258.76151772], shape=(17363,))

# %%
y_pred_4= model_4.predict(X=f2[['host_identity_verified']])
y_pred_4
# Out:
# array([1244.36216775, 1244.36216775, 1244.36216775, ..., 1244.36216775,
#        1244.36216775, 1244.36216775], shape=(17363,))

# %%
y_pred_5= model_5.predict(X=f2[['instant_bookable']])
y_pred_5
# Out:
# array([1217.07553721, 1217.07553721, 1217.07553721, ..., 1217.07553721,
#        1288.56018329, 1288.56018329], shape=(17363,))

# %%
y_pred_6= model_6.predict(X=f2[['bathrooms']])
y_pred_6
# Out:
# array([3.08122508, 3.08122508, 3.08122508, ..., 3.08122508, 3.08122508,
#        3.08122508], shape=(17363,))

# %%
y_pred_7= model_7.predict(X=f2[['review_scores_cleanliness']])
y_pred_7
# Out:
# array([1302.0259531 , 1187.63908363, 1206.70356187, ..., 1302.0259531 ,
#        1302.0259531 , 1302.0259531 ], shape=(17363,))

# %%
y_pred_8= model_8.predict(X=f2[['property_type']])
y_pred_8
# Out:
# array([1220.14615481, 1265.75619933, 1238.39017261, ..., 1238.39017261,
#        1238.39017261, 1238.39017261], shape=(17363,))

# %%
f2_c = f2.copy()

# %%
f2.insert(0, 'Pred_room', y_pred_1)
f2
# Out:
#          Pred_room  host_acceptance_rate  host_is_superhost  \
# 0      1247.175419                   100                  0
# 1      1247.175419                    93                  1
# 2      1247.175419                    57                  1
# 3      1247.175419                   100                  1
# 4      1247.175419                   100                  1
# ...            ...                   ...                ...
# 26572  1247.175419                   100                  0
# 26573  1247.175419                   100                  0
# 26574  1247.175419                   100                  0
# 26575  1247.175419                   100                  0
# 26581  1247.175419                   100                  1
#
#        host_identity_verified  property_type  room_type  instant_bookable  \
# 0                           1             23          1                 0
# 1                           1             13          1                 0
# 2                           1             19          1                 0
# 3                           1             19          1                 0
# 4                           1             17          1                 0
# ...                       ...            ...        ...               ...
# 26572                       1             19          1                 0
# 26573                       1              9          1                 0
# 26574                       1             19          1                 0
# 26575                       1             19          1                 1
# 26581                       1             19          1                 1
#
#        accommodates  bathrooms   price  review_scores_cleanliness
# 0               2.0        1.0  1093.1                       5.00
# 1               2.9        1.0  1511.6                       4.70
# 2               4.0        1.0  2029.0                       4.75
# 3               2.0        1.0  1140.0                       4.96
# 4               2.0        1.5  1093.1                       5.00
# ...             ...        ...     ...                        ...
# 26572           4.0        1.0   700.0                       5.00
# 26573           4.0        2.0  1900.0                       5.00
# 26574           2.0        1.0  1200.0                       5.00
# 26575           3.0        1.0  1358.0                       5.00
# 26581           2.0        1.0  1353.0                       5.00
#
# [17363 rows x 11 columns]

# %%
f2_c.insert(0, 'Pred_acceptance', y_pred_2)
f2_c.insert(0, 'Pred_superhost', y_pred_3)
f2_c.insert(0, 'Pred_identity', y_pred_4)
f2_c.insert(0, 'Pred_bookable', y_pred_5)
f2_c.insert(0, 'Pred_bathrooms', y_pred_6)
f2_c.insert(0, 'Pred_cleanliness', y_pred_7)
f2_c.insert(0, 'Pred_property', y_pred_8)

# %%
sns.scatterplot(x='room_type', y='price', color="blue", data = f2)
sns.scatterplot(x='room_type', y='Pred_room', color="red", data = f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.scatterplot(x='host_acceptance_rate', y='price', color="blue", data = f2_c)
sns.scatterplot(x='host_acceptance_rate', y='Pred_acceptance', color="red", data = f2_c)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
sns.scatterplot(x='host_is_superhost', y='price', color="blue", data = f2_c)
sns.scatterplot(x='host_is_superhost', y='Pred_superhost', color="red", data = f2_c)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
sns.scatterplot(x='host_identity_verified', y='price', color="blue", data = f2_c)
sns.scatterplot(x='host_identity_verified', y='Pred_identity', color="red", data = f2_c)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
sns.scatterplot(x='instant_bookable', y='price', color="blue", data = f2_c)
sns.scatterplot(x='instant_bookable', y='Pred_bookable', color="red", data = f2_c)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
sns.scatterplot(x='bathrooms', y='accommodates', color="blue", data = f2_c)
sns.scatterplot(x='bathrooms', y='Pred_bathrooms', color="red", data = f2_c)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
sns.scatterplot(x='review_scores_cleanliness', y='price', color="blue", data = f2_c)
sns.scatterplot(x='review_scores_cleanliness', y='Pred_cleanliness', color="red", data = f2_c)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
sns.scatterplot(x='property_type', y='price', color="blue", data = f2_c)
sns.scatterplot(x='property_type', y='Pred_property', color="red", data = f2_c)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
coef_Deter_1= model_1.score(X=Vars_Indep1, y=Vars_Dep1)
coef_Deter_1
# Out:
# 0.0

# %%
coef_Deter_2= model_2.score(X=Vars_Indep2, y=Vars_Dep2)
coef_Deter_2
# Out:
# 0.0017331250004086751

# %%
coef_Deter_3= model_3.score(X=Vars_Indep3, y=Vars_Dep3)
coef_Deter_3
# Out:
# 0.000438692181378042

# %%
coef_Deter_4= model_4.score(X=Vars_Indep4, y=Vars_Dep4)
coef_Deter_4
# Out:
# 0.001243324196534612

# %%
coef_Deter_5= model_5.score(X=Vars_Indep5, y=Vars_Dep5)
coef_Deter_5
# Out:
# 0.00500499399092591

# %%
coef_Deter_6= model_6.score(X=Vars_Indep6, y=Vars_Dep6)
coef_Deter_6
# Out:
# 0.17467174410575603

# %%
coef_Deter_7= model_7.score(X=Vars_Indep7, y=Vars_Dep7)
coef_Deter_7
# Out:
# 0.012506287448248332

# %%
coef_Deter_8= model_8.score(X=Vars_Indep8, y=Vars_Dep8)
coef_Deter_8
# Out:
# 0.005369658913734754

# %%
coef_Correl_1= np.sqrt(coef_Deter_1)
coef_Correl_1
# Out:
# np.float64(0.0)

# %%
coef_Correl_2= np.sqrt(coef_Deter_2)
coef_Correl_2
# Out:
# np.float64(0.041630817916642894)

# %%
coef_Correl_3= np.sqrt(coef_Deter_3)
coef_Correl_3
# Out:
# np.float64(0.02094497986100827)

# %%
coef_Correl_4= np.sqrt(coef_Deter_4)
coef_Correl_4
# Out:
# np.float64(0.035260802550914974)

# %%
coef_Correl_5= np.sqrt(coef_Deter_5)
coef_Correl_5
# Out:
# np.float64(0.07074598215394222)

# %%
coef_Correl_6= np.sqrt(coef_Deter_6)
coef_Correl_6
# Out:
# np.float64(0.4179374882751678)

# %%
coef_Correl_7= np.sqrt(coef_Deter_7)
coef_Correl_7
# Out:
# np.float64(0.11183151366340496)

# %%
coef_Correl_8= np.sqrt(coef_Deter_8)
coef_Correl_8
# Out:
# np.float64(0.07327795653356303)

# %%
df6 = f2.groupby(['room_type'])['room_type'].count()
df6
# Out:
# room_type
# 1    17363
# Name: room_type, dtype: int64

# %%
Corr_Factors=f2.corr()
Corr_Factors
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.216416
# host_is_superhost                NaN              0.216416           1.000000
# host_identity_verified           NaN             -0.030083           0.089277
# property_type                    NaN              0.005649          -0.011573
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN              0.249647           0.056226
# accommodates                     NaN              0.016170           0.033998
# bathrooms                        NaN              0.000208           0.063854
# price                            NaN              0.041631           0.020945
# review_scores_cleanliness        NaN             -0.070021           0.073298
#
#                            host_identity_verified  property_type  room_type  \
# Pred_room                                     NaN            NaN        NaN
# host_acceptance_rate                    -0.030083       0.005649        NaN
# host_is_superhost                        0.089277      -0.011573        NaN
# host_identity_verified                   1.000000       0.011611        NaN
# property_type                            0.011611       1.000000        NaN
# room_type                                     NaN            NaN        NaN
# instant_bookable                         0.069063       0.038075        NaN
# accommodates                             0.019736      -0.107425        NaN
# bathrooms                                0.066730      -0.071335        NaN
# price                                   -0.035261      -0.073278        NaN
# review_scores_cleanliness               -0.055379      -0.004975        NaN
#
#                            instant_bookable  accommodates  bathrooms  \
# Pred_room                               NaN           NaN        NaN
# host_acceptance_rate               0.249647      0.016170   0.000208
# host_is_superhost                  0.056226      0.033998   0.063854
# host_identity_verified             0.069063      0.019736   0.066730
# property_type                      0.038075     -0.107425  -0.071335
# room_type                               NaN           NaN        NaN
# instant_bookable                   1.000000     -0.009797   0.013756
# accommodates                      -0.009797      1.000000   0.417937
# bathrooms                          0.013756      0.417937   1.000000
# price                              0.070746      0.226007   0.295428
# review_scores_cleanliness         -0.085209     -0.023983   0.022138
#
#                               price  review_scores_cleanliness
# Pred_room                       NaN                        NaN
# host_acceptance_rate       0.041631                  -0.070021
# host_is_superhost          0.020945                   0.073298
# host_identity_verified    -0.035261                  -0.055379
# property_type             -0.073278                  -0.004975
# room_type                       NaN                        NaN
# instant_bookable           0.070746                  -0.085209
# accommodates               0.226007                  -0.023983
# bathrooms                  0.295428                   0.022138
# price                      1.000000                   0.111832
# review_scores_cleanliness  0.111832                   1.000000

# %%
Corr_Factors_pred=f2_c.corr()
Corr_Factors_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000          0.004975        0.071335
# Pred_cleanliness                0.004975          1.000000        0.022138
# Pred_bathrooms                  0.071335          0.022138        1.000000
# Pred_bookable                  -0.038075         -0.085209        0.013756
# Pred_identity                   0.011611          0.055379       -0.066730
# Pred_superhost                  0.011573          0.073298        0.063854
# Pred_acceptance                -0.005649         -0.070021        0.000208
# host_acceptance_rate           -0.005649         -0.070021        0.000208
# host_is_superhost               0.011573          0.073298        0.063854
# host_identity_verified         -0.011611         -0.055379        0.066730
# property_type                  -1.000000         -0.004975       -0.071335
# room_type                            NaN               NaN             NaN
# instant_bookable               -0.038075         -0.085209        0.013756
# accommodates                    0.107425         -0.023983        0.417937
# bathrooms                       0.071335          0.022138        1.000000
# price                           0.073278          0.111832        0.295428
# review_scores_cleanliness       0.004975          1.000000        0.022138
#
#                            Pred_bookable  Pred_identity  Pred_superhost  \
# Pred_property                  -0.038075       0.011611        0.011573
# Pred_cleanliness               -0.085209       0.055379        0.073298
# Pred_bathrooms                  0.013756      -0.066730        0.063854
# Pred_bookable                   1.000000      -0.069063        0.056226
# Pred_identity                  -0.069063       1.000000       -0.089277
# Pred_superhost                  0.056226      -0.089277        1.000000
# Pred_acceptance                 0.249647       0.030083        0.216416
# host_acceptance_rate            0.249647       0.030083        0.216416
# host_is_superhost               0.056226      -0.089277        1.000000
# host_identity_verified          0.069063      -1.000000        0.089277
# property_type                   0.038075      -0.011611       -0.011573
# room_type                            NaN            NaN             NaN
# instant_bookable                1.000000      -0.069063        0.056226
# accommodates                   -0.009797      -0.019736        0.033998
# bathrooms                       0.013756      -0.066730        0.063854
# price                           0.070746       0.035261        0.020945
# review_scores_cleanliness      -0.085209       0.055379        0.073298
#
#                            Pred_acceptance  host_acceptance_rate  \
# Pred_property                    -0.005649             -0.005649
# Pred_cleanliness                 -0.070021             -0.070021
# Pred_bathrooms                    0.000208              0.000208
# Pred_bookable                     0.249647              0.249647
# Pred_identity                     0.030083              0.030083
# Pred_superhost                    0.216416              0.216416
# Pred_acceptance                   1.000000              1.000000
# host_acceptance_rate              1.000000              1.000000
# host_is_superhost                 0.216416              0.216416
# host_identity_verified           -0.030083             -0.030083
# property_type                     0.005649              0.005649
# room_type                              NaN                   NaN
# instant_bookable                  0.249647              0.249647
# accommodates                      0.016170              0.016170
# bathrooms                         0.000208              0.000208
# price                             0.041631              0.041631
# review_scores_cleanliness        -0.070021             -0.070021
#
#                            host_is_superhost  host_identity_verified  \
# Pred_property                       0.011573               -0.011611
# Pred_cleanliness                    0.073298               -0.055379
# Pred_bathrooms                      0.063854                0.066730
# Pred_bookable                       0.056226                0.069063
# Pred_identity                      -0.089277               -1.000000
# Pred_superhost                      1.000000                0.089277
# Pred_acceptance                     0.216416               -0.030083
# host_acceptance_rate                0.216416               -0.030083
# host_is_superhost                   1.000000                0.089277
# host_identity_verified              0.089277                1.000000
# property_type                      -0.011573                0.011611
# room_type                                NaN                     NaN
# instant_bookable                    0.056226                0.069063
# accommodates                        0.033998                0.019736
# bathrooms                           0.063854                0.066730
# price                               0.020945               -0.035261
# review_scores_cleanliness           0.073298               -0.055379
#
#                            property_type  room_type  instant_bookable  \
# Pred_property                  -1.000000        NaN         -0.038075
# Pred_cleanliness               -0.004975        NaN         -0.085209
# Pred_bathrooms                 -0.071335        NaN          0.013756
# Pred_bookable                   0.038075        NaN          1.000000
# Pred_identity                  -0.011611        NaN         -0.069063
# Pred_superhost                 -0.011573        NaN          0.056226
# Pred_acceptance                 0.005649        NaN          0.249647
# host_acceptance_rate            0.005649        NaN          0.249647
# host_is_superhost              -0.011573        NaN          0.056226
# host_identity_verified          0.011611        NaN          0.069063
# property_type                   1.000000        NaN          0.038075
# room_type                            NaN        NaN               NaN
# instant_bookable                0.038075        NaN          1.000000
# accommodates                   -0.107425        NaN         -0.009797
# bathrooms                      -0.071335        NaN          0.013756
# price                          -0.073278        NaN          0.070746
# review_scores_cleanliness      -0.004975        NaN         -0.085209
#
#                            accommodates  bathrooms     price  \
# Pred_property                  0.107425   0.071335  0.073278
# Pred_cleanliness              -0.023983   0.022138  0.111832
# Pred_bathrooms                 0.417937   1.000000  0.295428
# Pred_bookable                 -0.009797   0.013756  0.070746
# Pred_identity                 -0.019736  -0.066730  0.035261
# Pred_superhost                 0.033998   0.063854  0.020945
# Pred_acceptance                0.016170   0.000208  0.041631
# host_acceptance_rate           0.016170   0.000208  0.041631
# host_is_superhost              0.033998   0.063854  0.020945
# host_identity_verified         0.019736   0.066730 -0.035261
# property_type                 -0.107425  -0.071335 -0.073278
# room_type                           NaN        NaN       NaN
# instant_bookable              -0.009797   0.013756  0.070746
# accommodates                   1.000000   0.417937  0.226007
# bathrooms                      0.417937   1.000000  0.295428
# price                          0.226007   0.295428  1.000000
# review_scores_cleanliness     -0.023983   0.022138  0.111832
#
#                            review_scores_cleanliness
# Pred_property                               0.004975
# Pred_cleanliness                            1.000000
# Pred_bathrooms                              0.022138
# Pred_bookable                              -0.085209
# Pred_identity                               0.055379
# Pred_superhost                              0.073298
# Pred_acceptance                            -0.070021
# host_acceptance_rate                       -0.070021
# host_is_superhost                           0.073298
# host_identity_verified                     -0.055379
# property_type                              -0.004975
# room_type                                        NaN
# instant_bookable                           -0.085209
# accommodates                               -0.023983
# bathrooms                                   0.022138
# price                                       0.111832
# review_scores_cleanliness                   1.000000

# %%
Corr_Factors1=abs(Corr_Factors)
Corr_Factors1
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.216416
# host_is_superhost                NaN              0.216416           1.000000
# host_identity_verified           NaN              0.030083           0.089277
# property_type                    NaN              0.005649           0.011573
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN              0.249647           0.056226
# accommodates                     NaN              0.016170           0.033998
# bathrooms                        NaN              0.000208           0.063854
# price                            NaN              0.041631           0.020945
# review_scores_cleanliness        NaN              0.070021           0.073298
#
#                            host_identity_verified  property_type  room_type  \
# Pred_room                                     NaN            NaN        NaN
# host_acceptance_rate                     0.030083       0.005649        NaN
# host_is_superhost                        0.089277       0.011573        NaN
# host_identity_verified                   1.000000       0.011611        NaN
# property_type                            0.011611       1.000000        NaN
# room_type                                     NaN            NaN        NaN
# instant_bookable                         0.069063       0.038075        NaN
# accommodates                             0.019736       0.107425        NaN
# bathrooms                                0.066730       0.071335        NaN
# price                                    0.035261       0.073278        NaN
# review_scores_cleanliness                0.055379       0.004975        NaN
#
#                            instant_bookable  accommodates  bathrooms  \
# Pred_room                               NaN           NaN        NaN
# host_acceptance_rate               0.249647      0.016170   0.000208
# host_is_superhost                  0.056226      0.033998   0.063854
# host_identity_verified             0.069063      0.019736   0.066730
# property_type                      0.038075      0.107425   0.071335
# room_type                               NaN           NaN        NaN
# instant_bookable                   1.000000      0.009797   0.013756
# accommodates                       0.009797      1.000000   0.417937
# bathrooms                          0.013756      0.417937   1.000000
# price                              0.070746      0.226007   0.295428
# review_scores_cleanliness          0.085209      0.023983   0.022138
#
#                               price  review_scores_cleanliness
# Pred_room                       NaN                        NaN
# host_acceptance_rate       0.041631                   0.070021
# host_is_superhost          0.020945                   0.073298
# host_identity_verified     0.035261                   0.055379
# property_type              0.073278                   0.004975
# room_type                       NaN                        NaN
# instant_bookable           0.070746                   0.085209
# accommodates               0.226007                   0.023983
# bathrooms                  0.295428                   0.022138
# price                      1.000000                   0.111832
# review_scores_cleanliness  0.111832                   1.000000

# %%
Corr_Factors1_pred=abs(Corr_Factors_pred)
Corr_Factors1_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000          0.004975        0.071335
# Pred_cleanliness                0.004975          1.000000        0.022138
# Pred_bathrooms                  0.071335          0.022138        1.000000
# Pred_bookable                   0.038075          0.085209        0.013756
# Pred_identity                   0.011611          0.055379        0.066730
# Pred_superhost                  0.011573          0.073298        0.063854
# Pred_acceptance                 0.005649          0.070021        0.000208
# host_acceptance_rate            0.005649          0.070021        0.000208
# host_is_superhost               0.011573          0.073298        0.063854
# host_identity_verified          0.011611          0.055379        0.066730
# property_type                   1.000000          0.004975        0.071335
# room_type                            NaN               NaN             NaN
# instant_bookable                0.038075          0.085209        0.013756
# accommodates                    0.107425          0.023983        0.417937
# bathrooms                       0.071335          0.022138        1.000000
# price                           0.073278          0.111832        0.295428
# review_scores_cleanliness       0.004975          1.000000        0.022138
#
#                            Pred_bookable  Pred_identity  Pred_superhost  \
# Pred_property                   0.038075       0.011611        0.011573
# Pred_cleanliness                0.085209       0.055379        0.073298
# Pred_bathrooms                  0.013756       0.066730        0.063854
# Pred_bookable                   1.000000       0.069063        0.056226
# Pred_identity                   0.069063       1.000000        0.089277
# Pred_superhost                  0.056226       0.089277        1.000000
# Pred_acceptance                 0.249647       0.030083        0.216416
# host_acceptance_rate            0.249647       0.030083        0.216416
# host_is_superhost               0.056226       0.089277        1.000000
# host_identity_verified          0.069063       1.000000        0.089277
# property_type                   0.038075       0.011611        0.011573
# room_type                            NaN            NaN             NaN
# instant_bookable                1.000000       0.069063        0.056226
# accommodates                    0.009797       0.019736        0.033998
# bathrooms                       0.013756       0.066730        0.063854
# price                           0.070746       0.035261        0.020945
# review_scores_cleanliness       0.085209       0.055379        0.073298
#
#                            Pred_acceptance  host_acceptance_rate  \
# Pred_property                     0.005649              0.005649
# Pred_cleanliness                  0.070021              0.070021
# Pred_bathrooms                    0.000208              0.000208
# Pred_bookable                     0.249647              0.249647
# Pred_identity                     0.030083              0.030083
# Pred_superhost                    0.216416              0.216416
# Pred_acceptance                   1.000000              1.000000
# host_acceptance_rate              1.000000              1.000000
# host_is_superhost                 0.216416              0.216416
# host_identity_verified            0.030083              0.030083
# property_type                     0.005649              0.005649
# room_type                              NaN                   NaN
# instant_bookable                  0.249647              0.249647
# accommodates                      0.016170              0.016170
# bathrooms                         0.000208              0.000208
# price                             0.041631              0.041631
# review_scores_cleanliness         0.070021              0.070021
#
#                            host_is_superhost  host_identity_verified  \
# Pred_property                       0.011573                0.011611
# Pred_cleanliness                    0.073298                0.055379
# Pred_bathrooms                      0.063854                0.066730
# Pred_bookable                       0.056226                0.069063
# Pred_identity                       0.089277                1.000000
# Pred_superhost                      1.000000                0.089277
# Pred_acceptance                     0.216416                0.030083
# host_acceptance_rate                0.216416                0.030083
# host_is_superhost                   1.000000                0.089277
# host_identity_verified              0.089277                1.000000
# property_type                       0.011573                0.011611
# room_type                                NaN                     NaN
# instant_bookable                    0.056226                0.069063
# accommodates                        0.033998                0.019736
# bathrooms                           0.063854                0.066730
# price                               0.020945                0.035261
# review_scores_cleanliness           0.073298                0.055379
#
#                            property_type  room_type  instant_bookable  \
# Pred_property                   1.000000        NaN          0.038075
# Pred_cleanliness                0.004975        NaN          0.085209
# Pred_bathrooms                  0.071335        NaN          0.013756
# Pred_bookable                   0.038075        NaN          1.000000
# Pred_identity                   0.011611        NaN          0.069063
# Pred_superhost                  0.011573        NaN          0.056226
# Pred_acceptance                 0.005649        NaN          0.249647
# host_acceptance_rate            0.005649        NaN          0.249647
# host_is_superhost               0.011573        NaN          0.056226
# host_identity_verified          0.011611        NaN          0.069063
# property_type                   1.000000        NaN          0.038075
# room_type                            NaN        NaN               NaN
# instant_bookable                0.038075        NaN          1.000000
# accommodates                    0.107425        NaN          0.009797
# bathrooms                       0.071335        NaN          0.013756
# price                           0.073278        NaN          0.070746
# review_scores_cleanliness       0.004975        NaN          0.085209
#
#                            accommodates  bathrooms     price  \
# Pred_property                  0.107425   0.071335  0.073278
# Pred_cleanliness               0.023983   0.022138  0.111832
# Pred_bathrooms                 0.417937   1.000000  0.295428
# Pred_bookable                  0.009797   0.013756  0.070746
# Pred_identity                  0.019736   0.066730  0.035261
# Pred_superhost                 0.033998   0.063854  0.020945
# Pred_acceptance                0.016170   0.000208  0.041631
# host_acceptance_rate           0.016170   0.000208  0.041631
# host_is_superhost              0.033998   0.063854  0.020945
# host_identity_verified         0.019736   0.066730  0.035261
# property_type                  0.107425   0.071335  0.073278
# room_type                           NaN        NaN       NaN
# instant_bookable               0.009797   0.013756  0.070746
# accommodates                   1.000000   0.417937  0.226007
# bathrooms                      0.417937   1.000000  0.295428
# price                          0.226007   0.295428  1.000000
# review_scores_cleanliness      0.023983   0.022138  0.111832
#
#                            review_scores_cleanliness
# Pred_property                               0.004975
# Pred_cleanliness                            1.000000
# Pred_bathrooms                              0.022138
# Pred_bookable                               0.085209
# Pred_identity                               0.055379
# Pred_superhost                              0.073298
# Pred_acceptance                             0.070021
# host_acceptance_rate                        0.070021
# host_is_superhost                           0.073298
# host_identity_verified                      0.055379
# property_type                               0.004975
# room_type                                        NaN
# instant_bookable                            0.085209
# accommodates                                0.023983
# bathrooms                                   0.022138
# price                                       0.111832
# review_scores_cleanliness                   1.000000

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1_pred, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >
