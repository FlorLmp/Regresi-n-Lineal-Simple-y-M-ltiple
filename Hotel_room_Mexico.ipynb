# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv('Mexico_limpio.csv')
df.head(5)
# Out:
#    Unnamed: 0                                              name  \
# 0           0                                       Villa Dante
# 1           1                                      Condesa Haus
# 2           2                 2 bedroom apt. deco bldg, Condesa
# 3           3  Beautiful light Studio Coyoacan- full equipped !
# 4           4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview host_name  host_since  \
# 0  Santa Fe Mall, Interloma Park and the Lion Des...      Dici  2010-06-28
# 1                        No se proporcionan detalles  Fernando  2010-08-09
# ...

# %%
#eliminamos la columna unnamed 
df= df.drop(['Unnamed: 0'], axis=1)
df.head(5)
# Out:
#                                                name  \
# 0                                       Villa Dante
# 1                                      Condesa Haus
# 2                 2 bedroom apt. deco bldg, Condesa
# 3  Beautiful light Studio Coyoacan- full equipped !
# 4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview host_name  host_since  \
# 0  Santa Fe Mall, Interloma Park and the Lion Des...      Dici  2010-06-28
# 1                        No se proporcionan detalles  Fernando  2010-08-09
# 2                        No se proporcionan detalles  Nicholas  2011-01-04
# ...

# %%
f1=df.iloc[ :  , [7,8,9,12,13,19,23,24,27,39] ]
f1
# Out:
#       host_acceptance_rate host_is_superhost host_identity_verified  \
# 0                      100                 f                      t
# 1                      93%                 t                      t
# 2                      57%                 t                      t
# 3                     100%                 t                      t
# 4                     100%                 t                      t
# ...                    ...               ...                    ...
# 26577                 100%                 t                      t
# 26578                 100%                 f                      t
# 26579                 100%                 f                      t
# 26580                 100%                 f                      t
# 26581                 100%                 t                      t
#
#                     property_type        room_type instant_bookable  \
# 0                    Entire villa  Entire home/apt                f
# ...

# %%
#convertimos string a tipos numéricos
f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
f1['property_type'] = encoder.fit_transform(f1['property_type'])

f1['host_acceptance_rate'] = f1['host_acceptance_rate'].astype(str).str.rstrip('%')
f1['host_acceptance_rate'] = pd.to_numeric(f1['host_acceptance_rate'], errors='coerce').fillna(0)

f1['room_type'] = f1['room_type'].map({
    'Entire home/apt': 1,
    'Private room': 2,
    'Shared room': 3,
    'Hotel room': 4
})
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32496\1540311677.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_32496\1540311677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# ...

# %%
#f2 = Entire home/apt
f2= f1[(f1["room_type"] == 1)]
#f3 = Private room
f3= f1[(f1["room_type"] == 2)]
#f4 = Shared room
f4= f1[(f1["room_type"] == 3)]
#f5 = Hotel room
f5= f1[(f1["room_type"] == 4)]

# %%
#imprimimos el scatter plot entre la variable dependiente (price) e indpendiente (room_type)
#para observar el comportamiento en su dispersión
from turtle import color

sns.scatterplot(x='room_type',y='price', color="blue", data=f5)
#sns.scatterplot(x='property_type',y='price', color="red", data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_acceptance_rate',y='price', color="blue", data=f5)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_is_superhost',y='price', color="blue", data=f5)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_identity_verified',y='price', color="blue", data=f5)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='instant_bookable',y='price', color="blue", data=f5)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='bathrooms',y='accommodates', color="blue", data=f5)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
from turtle import color

sns.scatterplot(x='review_scores_cleanliness',y='price', color="blue", data=f5)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
Vars_Indep1= f5 [['room_type']]
Vars_Dep1= f5 ['price']

# %%
Vars_Indep2= f5 [['host_acceptance_rate']]
Vars_Dep2= f5 ['price']

# %%
Vars_Indep3= f5 [['host_is_superhost']]
Vars_Dep3= f5 ['price']

# %%
Vars_Indep4= f5 [['host_identity_verified']]
Vars_Dep4= f5 ['price']

# %%
Vars_Indep5= f5 [['instant_bookable']]
Vars_Dep5= f5 ['price']

# %%
Vars_Indep6= f5 [['bathrooms']]
Vars_Dep6= f5 ['accommodates']

# %%
Vars_Indep7= f5 [['review_scores_cleanliness']]
Vars_Dep7= f5 ['price']

# %%
Vars_Indep8= f5 [['property_type']]
Vars_Dep8= f5 ['price']

# %%
from sklearn.linear_model import LinearRegression
model_1= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_2= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_3= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_4= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_5= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_6= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_7= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_8= LinearRegression()

# %%
type(model_1)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_2)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_3)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_4)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_5)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_6)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_7)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_8)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model_1.fit(X=Vars_Indep1, y=Vars_Dep1)
# Out:
# LinearRegression()

# %%
model_2.fit(X=Vars_Indep2, y=Vars_Dep2)
# Out:
# LinearRegression()

# %%
model_3.fit(X=Vars_Indep3, y=Vars_Dep3)
# Out:
# LinearRegression()

# %%
model_4.fit(X=Vars_Indep4, y=Vars_Dep4)
# Out:
# LinearRegression()

# %%
model_5.fit(X=Vars_Indep5, y=Vars_Dep5)
# Out:
# LinearRegression()

# %%
model_6.fit(X=Vars_Indep6, y=Vars_Dep6)
# Out:
# LinearRegression()

# %%
model_7.fit(X=Vars_Indep7, y=Vars_Dep7)
# Out:
# LinearRegression()

# %%
model_8.fit(X=Vars_Indep8, y=Vars_Dep8)
# Out:
# LinearRegression()

# %%
model_1.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['room_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(1291.1712000000002)}

# %%
model_2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.92851126]),
#  'rank_': 1,
#  'singular_': array([164.87871906]),
#  'intercept_': np.float64(1202.970058302758)}

# %%
model_3.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([230.30584677]),
#  'rank_': 1,
#  'singular_': array([4.87934422]),
#  'intercept_': np.float64(1232.2129032258067)}

# %%
model_4.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_identity_verified'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([111.74073529]),
#  'rank_': 1,
#  'singular_': array([5.21536192]),
#  'intercept_': np.float64(1215.1875000000002)}

# %%
model_5.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['instant_bookable'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-162.07706735]),
#  'rank_': 1,
#  'singular_': array([4.33220498]),
#  'intercept_': np.float64(1423.4260869565219)}

# %%
model_6.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['bathrooms'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([1.22337689]),
#  'rank_': 1,
#  'singular_': array([6.54702375]),
#  'intercept_': np.float64(1.3720183503361356)}

# %%
model_7.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-72.04598667]),
#  'rank_': 1,
#  'singular_': array([1.66464074]),
#  'intercept_': np.float64(1646.1677129014315)}

# %%
model_8.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([23.77597967]),
#  'rank_': 1,
#  'singular_': array([20.8038458]),
#  'intercept_': np.float64(-302.7704768946394)}

# %%
y_pred_1= model_1.predict(X=f5[['room_type']])
y_pred_1
# Out:
# array([1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
#        1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712, 1291.1712,
# ...

# %%
y_pred_2= model_2.predict(X=f5[['host_acceptance_rate']])
y_pred_2
# Out:
# array([1289.32160557, 1288.39309431, 1288.39309431, 1289.32160557,
#        1285.60756052, 1285.60756052, 1285.60756052, 1285.60756052,
#        1285.93777953, 1285.93777953, 1304.66973606, 1285.93777953,
#        1285.93777953, 1285.93777953, 1285.93777953, 1285.93777953,
# ...

# %%
y_pred_8= model_8.predict(X=f5[['property_type']])
y_pred_8
# Out:
# array([1337.77212015, 1242.66820148, 1242.66820148, 1337.77212015,
#        1337.77212015, 1337.77212015, 1337.77212015, 1337.77212015,
#        1337.77212015, 1218.89222181, 1337.77212015, 1337.77212015,
#        1218.89222181, 1337.77212015, 1337.77212015, 1195.11624214,
#        1242.66820148, 1337.77212015, 1337.77212015, 1337.77212015,
#        1195.11624214, 1337.77212015, 1337.77212015, 1337.77212015,
#        1337.77212015, 1337.77212015, 1242.66820148, 1337.77212015,
#        1337.77212015, 1313.99614048, 1313.99614048, 1313.99614048,
#        1313.99614048, 1313.99614048, 1313.99614048, 1313.99614048,
#        1313.99614048, 1313.99614048, 1313.99614048, 1313.99614048,
#        1313.99614048, 1218.89222181, 1242.66820148, 1337.77212015,
#        1242.66820148, 1337.77212015, 1337.77212015, 1337.77212015,
#        1337.77212015, 1242.66820148, 1218.89222181, 1242.66820148,
#        1266.44418115, 1218.89222181, 1337.77212015, 1337.77212015,
# ...

# %%
f5_c = f5.copy()

# %%
f5.insert(0, 'Pred_room', y_pred_1)
f5
# Out:
#        Pred_room  host_acceptance_rate  host_is_superhost  \
# 48     1291.1712                    93                  1
# 62     1291.1712                    92                  1
# 75     1291.1712                    92                  1
# 100    1291.1712                    93                  1
# 135    1291.1712                    89                  0
# ...          ...                   ...                ...
# 24907  1291.1712                   100                  0
# 24908  1291.1712                   100                  0
# 24909  1291.1712                   100                  0
# 24910  1291.1712                   100                  0
# 24911  1291.1712                   100                  0
#
#        host_identity_verified  property_type  room_type  instant_bookable  \
# 48                          1             69          4                 1
# 62                          1             65          4                 0
# ...

# %%
f5_c.insert(0, 'Pred_acceptance', y_pred_2)
f5_c.insert(0, 'Pred_superhost', y_pred_3)
f5_c.insert(0, 'Pred_identity', y_pred_4)
f5_c.insert(0, 'Pred_bookable', y_pred_5)
f5_c.insert(0, 'Pred_bathrooms', y_pred_6)
f5_c.insert(0, 'Pred_cleanliness', y_pred_7)
f5_c.insert(0, 'Pred_property', y_pred_8)

# %%
sns.scatterplot(x='room_type', y='price', color="blue", data = f5)
sns.scatterplot(x='room_type', y='Pred_room', color="red", data = f5)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.scatterplot(x='host_acceptance_rate', y='price', color="blue", data = f5_c)
sns.scatterplot(x='host_acceptance_rate', y='Pred_acceptance', color="red", data = f5_c)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
sns.scatterplot(x='host_is_superhost', y='price', color="blue", data = f5_c)
sns.scatterplot(x='host_is_superhost', y='Pred_superhost', color="red", data = f5_c)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
sns.scatterplot(x='host_identity_verified', y='price', color="blue", data = f5_c)
sns.scatterplot(x='host_identity_verified', y='Pred_identity', color="red", data = f5_c)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
sns.scatterplot(x='instant_bookable', y='price', color="blue", data = f5_c)
sns.scatterplot(x='instant_bookable', y='Pred_bookable', color="red", data = f5_c)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
sns.scatterplot(x='bathrooms', y='accommodates', color="blue", data = f5_c)
sns.scatterplot(x='bathrooms', y='Pred_bathrooms', color="red", data = f5_c)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
sns.scatterplot(x='review_scores_cleanliness', y='price', color="blue", data = f5_c)
sns.scatterplot(x='review_scores_cleanliness', y='Pred_cleanliness', color="red", data = f5_c)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
sns.scatterplot(x='property_type', y='price', color="blue", data = f5_c)
sns.scatterplot(x='property_type', y='Pred_property', color="red", data = f5_c)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
coef_Deter_1= model_1.score(X=Vars_Indep1, y=Vars_Dep1)
coef_Deter_1
# Out:
# 0.0

# %%
coef_Deter_2= model_2.score(X=Vars_Indep2, y=Vars_Dep2)
coef_Deter_2
# Out:
# 0.0014875658317249352

# %%
coef_Deter_3= model_3.score(X=Vars_Indep3, y=Vars_Dep3)
coef_Deter_3
# Out:
# 0.08015035963725525

# %%
coef_Deter_4= model_4.score(X=Vars_Indep4, y=Vars_Dep4)
coef_Deter_4
# Out:
# 0.02155582197416772

# %%
coef_Deter_5= model_5.score(X=Vars_Indep5, y=Vars_Dep5)
coef_Deter_5
# Out:
# 0.03129203223743138

# %%
coef_Deter_6= model_6.score(X=Vars_Indep6, y=Vars_Dep6)
coef_Deter_6
# Out:
# 0.29712134572686355

# %%
coef_Deter_7= model_7.score(X=Vars_Indep7, y=Vars_Dep7)
coef_Deter_7
# Out:
# 0.0009129211335544563

# %%
coef_Deter_8= model_8.score(X=Vars_Indep8, y=Vars_Dep8)
coef_Deter_8
# Out:
# 0.015528758212420501

# %%
coef_Correl_1= np.sqrt(coef_Deter_1)
coef_Correl_1
# Out:
# np.float64(0.0)

# %%
coef_Correl_2= np.sqrt(coef_Deter_2)
coef_Correl_2
# Out:
# np.float64(0.038568974989295936)

# %%
coef_Correl_3= np.sqrt(coef_Deter_3)
coef_Correl_3
# Out:
# np.float64(0.28310838849680037)

# %%
coef_Correl_4= np.sqrt(coef_Deter_4)
coef_Correl_4
# Out:
# np.float64(0.14681901094261507)

# %%
coef_Correl_5= np.sqrt(coef_Deter_5)
coef_Correl_5
# Out:
# np.float64(0.17689554046790262)

# %%
coef_Correl_6= np.sqrt(coef_Deter_6)
coef_Correl_6
# Out:
# np.float64(0.545088383408474)

# %%
coef_Correl_7= np.sqrt(coef_Deter_7)
coef_Correl_7
# Out:
# np.float64(0.030214584782095818)

# %%
coef_Correl_8= np.sqrt(coef_Deter_8)
coef_Correl_8
# Out:
# np.float64(0.12461443821813145)

# %%
df6 = f5.groupby(['room_type'])['room_type'].count()
df6
# Out:
# room_type
# 4    125
# Name: room_type, dtype: int64

# %%
Corr_Factors=f5.corr()
Corr_Factors
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.135806
# host_is_superhost                NaN              0.135806           1.000000
# host_identity_verified           NaN             -0.232957           0.402396
# property_type                    NaN              0.216623           0.243525
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN             -0.001658          -0.241836
# accommodates                     NaN              0.058428          -0.062976
# bathrooms                        NaN              0.091242          -0.246347
# price                            NaN              0.038569           0.283108
# review_scores_cleanliness        NaN             -0.077725          -0.421740
#
# ...

# %%
Corr_Factors_pred=f5_c.corr()
Corr_Factors_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000         -0.044850        0.153711
# Pred_cleanliness               -0.044850          1.000000       -0.230182
# Pred_bathrooms                  0.153711         -0.230182        1.000000
# Pred_bookable                   0.100747         -0.034766       -0.209230
# Pred_identity                  -0.335485          0.334681       -0.538525
# Pred_superhost                  0.243525          0.421740       -0.246347
# Pred_acceptance                 0.216623          0.077725        0.091242
# host_acceptance_rate            0.216623          0.077725        0.091242
# host_is_superhost               0.243525          0.421740       -0.246347
# host_identity_verified         -0.335485          0.334681       -0.538525
# property_type                   1.000000         -0.044850        0.153711
# ...

# %%
Corr_Factors1=abs(Corr_Factors)
Corr_Factors1
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.135806
# host_is_superhost                NaN              0.135806           1.000000
# host_identity_verified           NaN              0.232957           0.402396
# property_type                    NaN              0.216623           0.243525
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN              0.001658           0.241836
# accommodates                     NaN              0.058428           0.062976
# bathrooms                        NaN              0.091242           0.246347
# price                            NaN              0.038569           0.283108
# review_scores_cleanliness        NaN              0.077725           0.421740
#
# ...

# %%
Corr_Factors1_pred=abs(Corr_Factors_pred)
Corr_Factors1_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000          0.044850        0.153711
# Pred_cleanliness                0.044850          1.000000        0.230182
# Pred_bathrooms                  0.153711          0.230182        1.000000
# Pred_bookable                   0.100747          0.034766        0.209230
# Pred_identity                   0.335485          0.334681        0.538525
# Pred_superhost                  0.243525          0.421740        0.246347
# Pred_acceptance                 0.216623          0.077725        0.091242
# host_acceptance_rate            0.216623          0.077725        0.091242
# host_is_superhost               0.243525          0.421740        0.246347
# host_identity_verified          0.335485          0.334681        0.538525
# property_type                   1.000000          0.044850        0.153711
# ...

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1_pred, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >
