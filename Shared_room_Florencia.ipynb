# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv('Florencia_limpio.csv')
df.head(5)
# Out:
#    Unnamed: 0                                      name  \
# 0           0          A Residenza Martin  Classic room
# 1           1        Welcome at Corte Verde in Florence
# 2           2       Charming Gem - Oltrarno City centre
# 3           3            Central Double Shared Bathroom
# 4           4  Florence Central Double Private Bathroom
#
#                                          description  \
# 0  Nice, private and quiet double room, classic s...
# 1  Apartment at a 30 minute walk from Ponte Vecch...
# 2                                                  .
# 3  Double (or Twin) Room Shared Bathroom: comfort...
# 4  Double room private bathroom: comfortable, lar...
#
#                                neighborhood_overview     host_name  \
# 0                        No se proporcionan detalles  Officina 360
# 1                        No se proporcionan detalles         Lucia
# 2                        No se proporcionan detalles        Cesare
# ...

# %%
#eliminamos la columna unnamed 
df= df.drop(['Unnamed: 0'], axis=1)
df.head(5)
# Out:
#                                        name  \
# 0          A Residenza Martin  Classic room
# 1        Welcome at Corte Verde in Florence
# 2       Charming Gem - Oltrarno City centre
# 3            Central Double Shared Bathroom
# 4  Florence Central Double Private Bathroom
#
#                                          description  \
# 0  Nice, private and quiet double room, classic s...
# 1  Apartment at a 30 minute walk from Ponte Vecch...
# 2                                                  .
# 3  Double (or Twin) Room Shared Bathroom: comfort...
# 4  Double room private bathroom: comfortable, lar...
#
#                                neighborhood_overview     host_name  \
# 0                        No se proporcionan detalles  Officina 360
# 1                        No se proporcionan detalles         Lucia
# 2                        No se proporcionan detalles        Cesare
# 3  San Lorenzo Church, the market and Cappelle Me...       Lorenzo
# ...

# %%
f1=df.iloc[ :  , [7,8,9,12,13,19,23,24,27,39] ]
f1
# Out:
#       host_acceptance_rate host_is_superhost host_identity_verified  \
# 0                     100%                 f                      t
# 1                      25%                 f                      t
# 2                      65%                 f                      t
# 3                      71%                 f                      t
# 4                      71%                 f                      t
# ...                    ...               ...                    ...
# 12717                 100%                 f                      t
# 12718                 100%                 f                      t
# 12719                  100                 f                      t
# 12720                  97%                 t                      t
# 12721                 100%                 t                      t
#
#                             property_type        room_type instant_bookable  \
# ...

# %%
#convertimos string a tipos numéricos
f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
f1['property_type'] = encoder.fit_transform(f1['property_type'])

f1['host_acceptance_rate'] = f1['host_acceptance_rate'].astype(str).str.rstrip('%')
f1['host_acceptance_rate'] = pd.to_numeric(f1['host_acceptance_rate'], errors='coerce').fillna(0)

f1['room_type'] = f1['room_type'].map({
    'Entire home/apt': 1,
    'Private room': 2,
    'Shared room': 3,
    'Hotel room': 4
})
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_3044\1540311677.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_3044\1540311677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# ...

# %%
#f2 = Entire home/apt
f2= f1[(f1["room_type"] == 1)]
#f3 = Private room
f3= f1[(f1["room_type"] == 2)]
#f4 = Shared room
f4= f1[(f1["room_type"] == 3)]
#f5 = Hotel room
f5= f1[(f1["room_type"] == 4)]

# %%
#imprimimos el scatter plot entre la variable dependiente (price) e indpendiente (room_type)
#para observar el comportamiento en su dispersión
from turtle import color

sns.scatterplot(x='room_type',y='price', color="blue", data=f3)
#sns.scatterplot(x='property_type',y='price', color="red", data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_acceptance_rate',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_is_superhost',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_identity_verified',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='instant_bookable',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='bathrooms',y='accommodates', color="blue", data=f3)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
from turtle import color

sns.scatterplot(x='review_scores_cleanliness',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
Vars_Indep1= f3 [['room_type']]
Vars_Dep1= f3 ['price']

# %%
Vars_Indep2= f3 [['host_acceptance_rate']]
Vars_Dep2= f3 ['price']

# %%
Vars_Indep3= f3 [['host_is_superhost']]
Vars_Dep3= f3 ['price']

# %%
Vars_Indep4= f3 [['host_identity_verified']]
Vars_Dep4= f3 ['price']

# %%
Vars_Indep5= f3 [['instant_bookable']]
Vars_Dep5= f3 ['price']

# %%
Vars_Indep6= f3 [['bathrooms']]
Vars_Dep6= f3 ['accommodates']

# %%
Vars_Indep7= f3 [['review_scores_cleanliness']]
Vars_Dep7= f3 ['price']

# %%
Vars_Indep8= f3 [['property_type']]
Vars_Dep8= f3 ['price']

# %%
from sklearn.linear_model import LinearRegression
model_1= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_2= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_3= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_4= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_5= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_6= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_7= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_8= LinearRegression()

# %%
type(model_1)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_2)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_3)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_4)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_5)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_6)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_7)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_8)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model_1.fit(X=Vars_Indep1, y=Vars_Dep1)
# Out:
# LinearRegression()

# %%
model_2.fit(X=Vars_Indep2, y=Vars_Dep2)
# Out:
# LinearRegression()

# %%
model_3.fit(X=Vars_Indep3, y=Vars_Dep3)
# Out:
# LinearRegression()

# %%
model_4.fit(X=Vars_Indep4, y=Vars_Dep4)
# Out:
# LinearRegression()

# %%
model_5.fit(X=Vars_Indep5, y=Vars_Dep5)
# Out:
# LinearRegression()

# %%
model_6.fit(X=Vars_Indep6, y=Vars_Dep6)
# Out:
# LinearRegression()

# %%
model_7.fit(X=Vars_Indep7, y=Vars_Dep7)
# Out:
# LinearRegression()

# %%
model_8.fit(X=Vars_Indep8, y=Vars_Dep8)
# Out:
# LinearRegression()

# %%
model_1.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['room_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(134.47071253071255)}

# %%
model_2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.64203975]),
#  'rank_': 1,
#  'singular_': array([1088.62181655]),
#  'intercept_': np.float64(77.69357599032679)}

# %%
model_3.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-19.50917378]),
#  'rank_': 1,
#  'singular_': array([21.28632464]),
#  'intercept_': np.float64(140.99933530280646)}

# %%
model_4.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_identity_verified'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-54.63363368]),
#  'rank_': 1,
#  'singular_': array([10.50110559]),
#  'intercept_': np.float64(185.96324786324766)}

# %%
model_5.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['instant_bookable'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([72.85086656]),
#  'rank_': 1,
#  'singular_': array([22.54724769]),
#  'intercept_': np.float64(97.0608080808081)}

# %%
model_6.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['bathrooms'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.31964608]),
#  'rank_': 1,
#  'singular_': array([12.13386635]),
#  'intercept_': np.float64(1.8697885449469227)}

# %%
model_7.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([91.25529449]),
#  'rank_': 1,
#  'singular_': array([7.07933616]),
#  'intercept_': np.float64(-309.8394329756847)}

# %%
model_8.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([2.85936721]),
#  'rank_': 1,
#  'singular_': array([265.6428261]),
#  'intercept_': np.float64(47.633065166290606)}

# %%
y_pred_1= model_1.predict(X=f3[['room_type']])
y_pred_1
# Out:
# array([134.47071253, 134.47071253, 134.47071253, ..., 134.47071253,
#        134.47071253, 134.47071253], shape=(2035,))

# %%
y_pred_2= model_2.predict(X=f3[['host_acceptance_rate']])
y_pred_2
# Out:
# array([141.89755068, 123.27839802, 123.27839802, ..., 141.89755068,
#        141.89755068, 141.89755068], shape=(2035,))

# %%
y_pred_3= model_3.predict(X=f3[['host_is_superhost']])
y_pred_3
# Out:
# array([140.9993353 , 140.9993353 , 140.9993353 , ..., 121.49016153,
#        121.49016153, 121.49016153], shape=(2035,))

# %%
y_pred_4= model_4.predict(X=f3[['host_identity_verified']])
y_pred_4
# Out:
# array([131.32961418, 131.32961418, 131.32961418, ..., 131.32961418,
#        131.32961418, 131.32961418], shape=(2035,))

# %%
y_pred_5= model_5.predict(X=f3[['instant_bookable']])
y_pred_5
# Out:
# array([169.91167464,  97.06080808,  97.06080808, ..., 169.91167464,
#        169.91167464, 169.91167464], shape=(2035,))

# %%
y_pred_6= model_6.predict(X=f3[['bathrooms']])
y_pred_6
# Out:
# array([2.18943462, 2.25336384, 2.18943462, ..., 2.18943462, 2.18943462,
#        2.18943462], shape=(2035,))

# %%
y_pred_7= model_7.predict(X=f3[['review_scores_cleanliness']])
y_pred_7
# Out:
# array([134.57385119, 109.93492168, 108.10981579, ..., 146.43703948,
#        146.43703948, 146.43703948], shape=(2035,))

# %%
y_pred_8= model_8.predict(X=f3[['property_type']])
y_pred_8
# Out:
# array([141.99218314, 130.55471429, 130.55471429, ..., 139.13281592,
#        139.13281592, 139.13281592], shape=(2035,))

# %%
f3_c = f3.copy()

# %%
f3.insert(0, 'Pred_room', y_pred_1)
f3
# Out:
#         Pred_room  host_acceptance_rate  host_is_superhost  \
# 0      134.470713                   100                  0
# 3      134.470713                    71                  0
# 4      134.470713                    71                  0
# 9      134.470713                   100                  0
# 10     134.470713                   100                  0
# ...           ...                   ...                ...
# 12687  134.470713                    89                  0
# 12690  134.470713                    81                  0
# 12700  134.470713                   100                  1
# 12702  134.470713                   100                  1
# 12703  134.470713                   100                  1
#
#        host_identity_verified  property_type  room_type  instant_bookable  \
# 0                           1             33          2                 1
# 3                           1             29          2                 0
# ...

# %%
f3_c.insert(0, 'Pred_acceptance', y_pred_2)
f3_c.insert(0, 'Pred_superhost', y_pred_3)
f3_c.insert(0, 'Pred_identity', y_pred_4)
f3_c.insert(0, 'Pred_bookable', y_pred_5)
f3_c.insert(0, 'Pred_bathrooms', y_pred_6)
f3_c.insert(0, 'Pred_cleanliness', y_pred_7)
f3_c.insert(0, 'Pred_property', y_pred_8)

# %%
sns.scatterplot(x='room_type', y='price', color="blue", data = f3)
sns.scatterplot(x='room_type', y='Pred_room', color="red", data = f3)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.scatterplot(x='host_acceptance_rate', y='price', color="blue", data = f3_c)
sns.scatterplot(x='host_acceptance_rate', y='Pred_acceptance', color="red", data = f3_c)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
sns.scatterplot(x='host_is_superhost', y='price', color="blue", data = f3_c)
sns.scatterplot(x='host_is_superhost', y='Pred_superhost', color="red", data = f3_c)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
sns.scatterplot(x='host_identity_verified', y='price', color="blue", data = f3_c)
sns.scatterplot(x='host_identity_verified', y='Pred_identity', color="red", data = f3_c)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
sns.scatterplot(x='instant_bookable', y='price', color="blue", data = f3_c)
sns.scatterplot(x='instant_bookable', y='Pred_bookable', color="red", data = f3_c)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
sns.scatterplot(x='bathrooms', y='accommodates', color="blue", data = f3_c)
sns.scatterplot(x='bathrooms', y='Pred_bathrooms', color="red", data = f3_c)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
sns.scatterplot(x='review_scores_cleanliness', y='price', color="blue", data = f3_c)
sns.scatterplot(x='review_scores_cleanliness', y='Pred_cleanliness', color="red", data = f3_c)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
sns.scatterplot(x='property_type', y='price', color="blue", data = f3_c)
sns.scatterplot(x='property_type', y='Pred_property', color="red", data = f3_c)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
coef_Deter_1= model_1.score(X=Vars_Indep1, y=Vars_Dep1)
coef_Deter_1
# Out:
# 0.0

# %%
coef_Deter_2= model_2.score(X=Vars_Indep2, y=Vars_Dep2)
coef_Deter_2
# Out:
# 0.033452366338933115

# %%
coef_Deter_3= model_3.score(X=Vars_Indep3, y=Vars_Dep3)
coef_Deter_3
# Out:
# 0.011809406289104873

# %%
coef_Deter_4= model_4.score(X=Vars_Indep4, y=Vars_Dep4)
coef_Deter_4
# Out:
# 0.02253923496749477

# %%
coef_Deter_5= model_5.score(X=Vars_Indep5, y=Vars_Dep5)
coef_Deter_5
# Out:
# 0.18475894037905483

# %%
coef_Deter_6= model_6.score(X=Vars_Indep6, y=Vars_Dep6)
coef_Deter_6
# Out:
# 0.010523101294387271

# %%
coef_Deter_7= model_7.score(X=Vars_Indep7, y=Vars_Dep7)
coef_Deter_7
# Out:
# 0.02857920605148212

# %%
coef_Deter_8= model_8.score(X=Vars_Indep8, y=Vars_Dep8)
coef_Deter_8
# Out:
# 0.03950799558500795

# %%
coef_Correl_1= np.sqrt(coef_Deter_1)
coef_Correl_1
# Out:
# np.float64(0.0)

# %%
coef_Correl_2= np.sqrt(coef_Deter_2)
coef_Correl_2
# Out:
# np.float64(0.18289988064220578)

# %%
coef_Correl_3= np.sqrt(coef_Deter_3)
coef_Correl_3
# Out:
# np.float64(0.1086710922421638)

# %%
coef_Correl_4= np.sqrt(coef_Deter_4)
coef_Correl_4
# Out:
# np.float64(0.1501307262604653)

# %%
coef_Correl_5= np.sqrt(coef_Deter_5)
coef_Correl_5
# Out:
# np.float64(0.4298359458898881)

# %%
coef_Correl_6= np.sqrt(coef_Deter_6)
coef_Correl_6
# Out:
# np.float64(0.1025821685010961)

# %%
coef_Correl_7= np.sqrt(coef_Deter_7)
coef_Correl_7
# Out:
# np.float64(0.16905385547653778)

# %%
coef_Correl_8= np.sqrt(coef_Deter_8)
coef_Correl_8
# Out:
# np.float64(0.19876618320279724)

# %%
df6 = f3.groupby(['room_type'])['room_type'].count()
df6
# Out:
# room_type
# 2    2035
# Name: room_type, dtype: int64

# %%
Corr_Factors=f3.corr()
Corr_Factors
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.155722
# host_is_superhost                NaN              0.155722           1.000000
# host_identity_verified           NaN             -0.000035           0.117001
# property_type                    NaN              0.110092          -0.072093
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN              0.423097          -0.043135
# accommodates                     NaN              0.073525          -0.069551
# bathrooms                        NaN             -0.038704          -0.054282
# price                            NaN              0.182900          -0.108671
# review_scores_cleanliness        NaN             -0.034421           0.093167
#
# ...

# %%
Corr_Factors_pred=f3_c.corr()
Corr_Factors_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000         -0.040057       -0.039674
# Pred_cleanliness               -0.040057          1.000000       -0.112214
# Pred_bathrooms                 -0.039674         -0.112214        1.000000
# Pred_bookable                   0.104489         -0.021607        0.009978
# Pred_identity                  -0.039876          0.121901       -0.009881
# Pred_superhost                  0.072093         -0.093167        0.054282
# Pred_acceptance                 0.110092         -0.034421       -0.038704
# host_acceptance_rate            0.110092         -0.034421       -0.038704
# host_is_superhost              -0.072093          0.093167       -0.054282
# host_identity_verified          0.039876         -0.121901        0.009881
# property_type                   1.000000         -0.040057       -0.039674
# ...

# %%
Corr_Factors1=abs(Corr_Factors)
Corr_Factors1
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.155722
# host_is_superhost                NaN              0.155722           1.000000
# host_identity_verified           NaN              0.000035           0.117001
# property_type                    NaN              0.110092           0.072093
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN              0.423097           0.043135
# accommodates                     NaN              0.073525           0.069551
# bathrooms                        NaN              0.038704           0.054282
# price                            NaN              0.182900           0.108671
# review_scores_cleanliness        NaN              0.034421           0.093167
#
# ...

# %%
Corr_Factors1_pred=abs(Corr_Factors_pred)
Corr_Factors1_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000          0.040057        0.039674
# Pred_cleanliness                0.040057          1.000000        0.112214
# Pred_bathrooms                  0.039674          0.112214        1.000000
# Pred_bookable                   0.104489          0.021607        0.009978
# Pred_identity                   0.039876          0.121901        0.009881
# Pred_superhost                  0.072093          0.093167        0.054282
# Pred_acceptance                 0.110092          0.034421        0.038704
# host_acceptance_rate            0.110092          0.034421        0.038704
# host_is_superhost               0.072093          0.093167        0.054282
# host_identity_verified          0.039876          0.121901        0.009881
# property_type                   1.000000          0.040057        0.039674
# ...

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1_pred, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >
