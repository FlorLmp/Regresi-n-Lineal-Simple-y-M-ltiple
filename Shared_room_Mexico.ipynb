# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv('Mexico_limpio.csv')
df.head(5)
# Out:
#    Unnamed: 0                                              name  \
# 0           0                                       Villa Dante
# 1           1                                      Condesa Haus
# 2           2                 2 bedroom apt. deco bldg, Condesa
# 3           3  Beautiful light Studio Coyoacan- full equipped !
# 4           4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview host_name  host_since  \
# 0  Santa Fe Mall, Interloma Park and the Lion Des...      Dici  2010-06-28
# 1                        No se proporcionan detalles  Fernando  2010-08-09
# 2                        No se proporcionan detalles  Nicholas  2011-01-04
# 3  Coyoacan is a beautiful neighborhood famous fo...    Trisha  2010-08-24
# 4  Is located in the best area of Mexico City, Po...    Andrea  2011-04-27
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  a few days or more                 0%                  100
# 1      within an hour               100%                  93%
# 2      within an hour                71%                  57%
# 3  within a few hours               100%                 100%
# 4      within an hour               100%                 100%
#
#   host_is_superhost  ... review_scores_cleanliness review_scores_checkin  \
# 0                 f  ...                      5.00                  5.00
# 1                 t  ...                      4.70                  4.87
# 2                 t  ...                      4.75                  4.94
# 3                 t  ...                      4.96                  4.96
# 4                 t  ...                      5.00                  5.00
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        5.00                   4.80                4.70
# 1                        4.78                   4.98                4.48
# 2                        4.92                   4.98                4.91
# 3                        4.98                   4.96                4.92
# 4                        4.73                   4.91                4.82
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                            1.0                                         1.0
# 1                            8.0                                         4.0
# 2                            2.0                                         2.0
# 3                            3.0                                         2.0
# 4                            3.0                                         3.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          1.0
# 2                                          0.0
# 3                                          1.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              1.70
# 1                                         0.0              0.41
# 2                                         0.0              0.31
# 3                                         0.0              0.83
# 4                                         0.0              0.11
#
# [5 rows x 50 columns]

# %%
#eliminamos la columna unnamed 
df= df.drop(['Unnamed: 0'], axis=1)
df.head(5)
# Out:
#                                                name  \
# 0                                       Villa Dante
# 1                                      Condesa Haus
# 2                 2 bedroom apt. deco bldg, Condesa
# 3  Beautiful light Studio Coyoacan- full equipped !
# 4                                NEW  DESIGNER LOFT
#
#                                          description  \
# 0  Dentro de Villa un estudio de arte con futon, ...
# 1  A new concept of hosting in mexico through a b...
# 2  Comfortably furnished, sunny, 2 bedroom apt., ...
# 3  COYOACAN designer studio quiet & safe! well eq...
# 4  Is the best ever place triple L <br />Location...
#
#                                neighborhood_overview host_name  host_since  \
# 0  Santa Fe Mall, Interloma Park and the Lion Des...      Dici  2010-06-28
# 1                        No se proporcionan detalles  Fernando  2010-08-09
# 2                        No se proporcionan detalles  Nicholas  2011-01-04
# 3  Coyoacan is a beautiful neighborhood famous fo...    Trisha  2010-08-24
# 4  Is located in the best area of Mexico City, Po...    Andrea  2011-04-27
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  a few days or more                 0%                  100
# 1      within an hour               100%                  93%
# 2      within an hour                71%                  57%
# 3  within a few hours               100%                 100%
# 4      within an hour               100%                 100%
#
#   host_is_superhost host_identity_verified  ... review_scores_cleanliness  \
# 0                 f                      t  ...                      5.00
# 1                 t                      t  ...                      4.70
# 2                 t                      t  ...                      4.75
# 3                 t                      t  ...                      4.96
# 4                 t                      t  ...                      5.00
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  5.00                        5.00                   4.80
# 1                  4.87                        4.78                   4.98
# 2                  4.94                        4.92                   4.98
# 3                  4.96                        4.98                   4.96
# 4                  5.00                        4.73                   4.91
#
#   review_scores_value calculated_host_listings_count  \
# 0                4.70                            1.0
# 1                4.48                            8.0
# 2                4.91                            2.0
# 3                4.92                            3.0
# 4                4.82                            3.0
#
#   calculated_host_listings_count_entire_homes  \
# 0                                         1.0
# 1                                         4.0
# 2                                         2.0
# 3                                         2.0
# 4                                         3.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          1.0
# 2                                          0.0
# 3                                          1.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              1.70
# 1                                         0.0              0.41
# 2                                         0.0              0.31
# 3                                         0.0              0.83
# 4                                         0.0              0.11
#
# [5 rows x 49 columns]

# %%
f1=df.iloc[ :  , [7,8,9,12,13,19,23,24,27,39] ]
f1
# Out:
#       host_acceptance_rate host_is_superhost host_identity_verified  \
# 0                      100                 f                      t
# 1                      93%                 t                      t
# 2                      57%                 t                      t
# 3                     100%                 t                      t
# 4                     100%                 t                      t
# ...                    ...               ...                    ...
# 26577                 100%                 t                      t
# 26578                 100%                 f                      t
# 26579                 100%                 f                      t
# 26580                 100%                 f                      t
# 26581                 100%                 t                      t
#
#                     property_type        room_type instant_bookable  \
# 0                    Entire villa  Entire home/apt                f
# 1                     Entire home  Entire home/apt                f
# 2              Entire rental unit  Entire home/apt                f
# 3              Entire rental unit  Entire home/apt                f
# 4                     Entire loft  Entire home/apt                f
# ...                           ...              ...              ...
# 26577  Private room in guesthouse     Private room                t
# 26578               Room in hotel     Private room                t
# 26579               Room in hotel     Private room                t
# 26580               Room in hotel     Private room                t
# 26581          Entire rental unit  Entire home/apt                t
#
#        accommodates  bathrooms   price  review_scores_cleanliness
# 0               2.0        1.0  1093.1                       5.00
# 1               2.9        1.0  1511.6                       4.70
# 2               4.0        1.0  2029.0                       4.75
# 3               2.0        1.0  1140.0                       4.96
# 4               2.0        1.5  1093.1                       5.00
# ...             ...        ...     ...                        ...
# 26577           4.0        1.0   488.0                       5.00
# 26578           2.0        1.0  1093.1                       5.00
# 26579           2.0        1.0  2700.0                       5.00
# 26580           2.0        1.0  2600.0                       5.00
# 26581           2.0        1.0  1353.0                       5.00
#
# [26582 rows x 10 columns]

# %%
#convertimos string a tipos numéricos
f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
f1['property_type'] = encoder.fit_transform(f1['property_type'])

f1['host_acceptance_rate'] = f1['host_acceptance_rate'].astype(str).str.rstrip('%')
f1['host_acceptance_rate'] = pd.to_numeric(f1['host_acceptance_rate'], errors='coerce').fillna(0)

f1['room_type'] = f1['room_type'].map({
    'Entire home/apt': 1,
    'Private room': 2,
    'Shared room': 3,
    'Hotel room': 4
})
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_is_superhost'] = f1['host_is_superhost'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_identity_verified'] = f1['host_identity_verified'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['instant_bookable'] = f1['instant_bookable'].replace({'f': 0, 't': 1})
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['property_type'] = encoder.fit_transform(f1['property_type'])
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_acceptance_rate'] = f1['host_acceptance_rate'].astype(str).str.rstrip('%')
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['host_acceptance_rate'] = pd.to_numeric(f1['host_acceptance_rate'], errors='coerce').fillna(0)
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_34400\1540311677.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f1['room_type'] = f1['room_type'].map({

# %%
#f2 = Entire home/apt
f2= f1[(f1["room_type"] == 1)]
#f3 = Private room
f3= f1[(f1["room_type"] == 2)]
#f4 = Shared room
f4= f1[(f1["room_type"] == 3)]
#f5 = Hotel room
f5= f1[(f1["room_type"] == 4)]

# %%
#imprimimos el scatter plot entre la variable dependiente (price) e indpendiente (room_type)
#para observar el comportamiento en su dispersión
from turtle import color

sns.scatterplot(x='room_type',y='price', color="blue", data=f3)
#sns.scatterplot(x='property_type',y='price', color="red", data=f2)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_acceptance_rate',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_is_superhost',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='host_identity_verified',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='instant_bookable',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
from turtle import color

sns.scatterplot(x='bathrooms',y='accommodates', color="blue", data=f3)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
from turtle import color

sns.scatterplot(x='review_scores_cleanliness',y='price', color="blue", data=f3)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
Vars_Indep1= f3 [['room_type']]
Vars_Dep1= f3 ['price']

# %%
Vars_Indep2= f3 [['host_acceptance_rate']]
Vars_Dep2= f3 ['price']

# %%
Vars_Indep3= f3 [['host_is_superhost']]
Vars_Dep3= f3 ['price']

# %%
Vars_Indep4= f3 [['host_identity_verified']]
Vars_Dep4= f3 ['price']

# %%
Vars_Indep5= f3 [['instant_bookable']]
Vars_Dep5= f3 ['price']

# %%
Vars_Indep6= f3 [['bathrooms']]
Vars_Dep6= f3 ['accommodates']

# %%
Vars_Indep7= f3 [['review_scores_cleanliness']]
Vars_Dep7= f3 ['price']

# %%
Vars_Indep8= f3 [['property_type']]
Vars_Dep8= f3 ['price']

# %%
from sklearn.linear_model import LinearRegression
model_1= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_2= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_3= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_4= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_5= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_6= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_7= LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
model_8= LinearRegression()

# %%
type(model_1)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_2)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_3)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_4)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_5)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_6)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_7)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
type(model_8)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model_1.fit(X=Vars_Indep1, y=Vars_Dep1)
# Out:
# LinearRegression()

# %%
model_2.fit(X=Vars_Indep2, y=Vars_Dep2)
# Out:
# LinearRegression()

# %%
model_3.fit(X=Vars_Indep3, y=Vars_Dep3)
# Out:
# LinearRegression()

# %%
model_4.fit(X=Vars_Indep4, y=Vars_Dep4)
# Out:
# LinearRegression()

# %%
model_5.fit(X=Vars_Indep5, y=Vars_Dep5)
# Out:
# LinearRegression()

# %%
model_6.fit(X=Vars_Indep6, y=Vars_Dep6)
# Out:
# LinearRegression()

# %%
model_7.fit(X=Vars_Indep7, y=Vars_Dep7)
# Out:
# LinearRegression()

# %%
model_8.fit(X=Vars_Indep8, y=Vars_Dep8)
# Out:
# LinearRegression()

# %%
model_1.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['room_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.]),
#  'rank_': 0,
#  'singular_': array([0.]),
#  'intercept_': np.float64(811.6864258598873)}

# %%
model_2.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([2.30037995]),
#  'rank_': 1,
#  'singular_': array([2549.50462781]),
#  'intercept_': np.float64(613.9040287013613)}

# %%
model_3.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_is_superhost'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-125.94390558]),
#  'rank_': 1,
#  'singular_': array([41.92558581]),
#  'intercept_': np.float64(847.1239955178472)}

# %%
model_4.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_identity_verified'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([-635.75587412]),
#  'rank_': 1,
#  'singular_': array([23.85192443]),
#  'intercept_': np.float64(1402.6841503268051)}

# %%
model_5.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['instant_bookable'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([66.70173871]),
#  'rank_': 1,
#  'singular_': array([43.86528376]),
#  'intercept_': np.float64(789.6264352011002)}

# %%
model_6.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['bathrooms'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([0.15942032]),
#  'rank_': 1,
#  'singular_': array([37.09847383]),
#  'intercept_': np.float64(1.7491727928127403)}

# %%
model_7.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['review_scores_cleanliness'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([636.54968667]),
#  'rank_': 1,
#  'singular_': array([14.61294383]),
#  'intercept_': np.float64(-2291.2776474326)}

# %%
model_8.__dict__
# Out:
# {'fit_intercept': True,
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['property_type'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([7.55857994]),
#  'rank_': 1,
#  'singular_': array([849.64482764]),
#  'intercept_': np.float64(451.1265986027852)}

# %%
y_pred_1= model_1.predict(X=f3[['room_type']])
y_pred_1
# Out:
# array([811.68642586, 811.68642586, 811.68642586, ..., 811.68642586,
#        811.68642586, 811.68642586], shape=(8693,))

# %%
y_pred_2= model_2.predict(X=f3[['host_acceptance_rate']])
y_pred_2
# Out:
# array([843.94202381, 793.33366489, 843.94202381, ..., 843.94202381,
#        843.94202381, 843.94202381], shape=(8693,))

# %%
y_pred_3= model_3.predict(X=f3[['host_is_superhost']])
y_pred_3
# Out:
# array([847.12399552, 721.18008994, 721.18008994, ..., 847.12399552,
#        847.12399552, 847.12399552], shape=(8693,))

# %%
y_pred_4= model_4.predict(X=f3[['host_identity_verified']])
y_pred_4
# Out:
# array([1402.68415033,  766.9282762 ,  766.9282762 , ...,  766.9282762 ,
#         766.9282762 ,  766.9282762 ], shape=(8693,))

# %%
y_pred_5= model_5.predict(X=f3[['instant_bookable']])
y_pred_5
# Out:
# array([789.6264352 , 789.6264352 , 789.6264352 , ..., 856.32817391,
#        856.32817391, 856.32817391], shape=(8693,))

# %%
y_pred_6= model_6.predict(X=f3[['bathrooms']])
y_pred_6
# Out:
# array([1.90859312, 1.90859312, 1.98830328, ..., 1.90859312, 1.90859312,
#        1.90859312], shape=(8693,))

# %%
y_pred_7= model_7.predict(X=f3[['review_scores_cleanliness']])
y_pred_7
# Out:
# array([891.47078593, 643.21640813, 840.546811  , ..., 891.47078593,
#        891.47078593, 891.47078593], shape=(8693,))

# %%
y_pred_8= model_8.predict(X=f3[['property_type']])
y_pred_8
# Out:
# array([655.208257  , 851.73133546, 783.704116  , ..., 965.11003457,
#        965.11003457, 965.11003457], shape=(8693,))

# %%
f3_c = f3.copy()

# %%
f3.insert(0, 'Pred_room', y_pred_1)
f3
# Out:
#         Pred_room  host_acceptance_rate  host_is_superhost  \
# 5      811.686426                   100                  0
# 7      811.686426                    78                  1
# 10     811.686426                   100                  1
# 11     811.686426                   100                  0
# 12     811.686426                    75                  0
# ...           ...                   ...                ...
# 26576  811.686426                   100                  0
# 26577  811.686426                   100                  1
# 26578  811.686426                   100                  0
# 26579  811.686426                   100                  0
# 26580  811.686426                   100                  0
#
#        host_identity_verified  property_type  room_type  instant_bookable  \
# 5                           0             27          2                 0
# 7                           1             53          2                 0
# 10                          1             44          2                 0
# 11                          0             35          2                 0
# 12                          1             42          2                 0
# ...                       ...            ...        ...               ...
# 26576                       1             44          2                 1
# 26577                       1             43          2                 1
# 26578                       1             68          2                 1
# 26579                       1             68          2                 1
# 26580                       1             68          2                 1
#
#        accommodates  bathrooms   price  review_scores_cleanliness
# 5               2.0        1.0  1511.6                       5.00
# 7               2.0        1.0   335.0                       4.61
# 10              1.0        1.5   384.0                       4.92
# 11              1.0        1.0   947.0                       4.97
# 12              2.0        1.0  1200.0                       4.97
# ...             ...        ...     ...                        ...
# 26576           2.0        2.0   262.0                       5.00
# 26577           4.0        1.0   488.0                       5.00
# 26578           2.0        1.0  1093.1                       5.00
# 26579           2.0        1.0  2700.0                       5.00
# 26580           2.0        1.0  2600.0                       5.00
#
# [8693 rows x 11 columns]

# %%
f3_c.insert(0, 'Pred_acceptance', y_pred_2)
f3_c.insert(0, 'Pred_superhost', y_pred_3)
f3_c.insert(0, 'Pred_identity', y_pred_4)
f3_c.insert(0, 'Pred_bookable', y_pred_5)
f3_c.insert(0, 'Pred_bathrooms', y_pred_6)
f3_c.insert(0, 'Pred_cleanliness', y_pred_7)
f3_c.insert(0, 'Pred_property', y_pred_8)

# %%
sns.scatterplot(x='room_type', y='price', color="blue", data = f3)
sns.scatterplot(x='room_type', y='Pred_room', color="red", data = f3)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.scatterplot(x='host_acceptance_rate', y='price', color="blue", data = f3_c)
sns.scatterplot(x='host_acceptance_rate', y='Pred_acceptance', color="red", data = f3_c)
# Out:
# <Axes: xlabel='host_acceptance_rate', ylabel='price'>

# %%
sns.scatterplot(x='host_is_superhost', y='price', color="blue", data = f3_c)
sns.scatterplot(x='host_is_superhost', y='Pred_superhost', color="red", data = f3_c)
# Out:
# <Axes: xlabel='host_is_superhost', ylabel='price'>

# %%
sns.scatterplot(x='host_identity_verified', y='price', color="blue", data = f3_c)
sns.scatterplot(x='host_identity_verified', y='Pred_identity', color="red", data = f3_c)
# Out:
# <Axes: xlabel='host_identity_verified', ylabel='price'>

# %%
sns.scatterplot(x='instant_bookable', y='price', color="blue", data = f3_c)
sns.scatterplot(x='instant_bookable', y='Pred_bookable', color="red", data = f3_c)
# Out:
# <Axes: xlabel='instant_bookable', ylabel='price'>

# %%
sns.scatterplot(x='bathrooms', y='accommodates', color="blue", data = f3_c)
sns.scatterplot(x='bathrooms', y='Pred_bathrooms', color="red", data = f3_c)
# Out:
# <Axes: xlabel='bathrooms', ylabel='accommodates'>

# %%
sns.scatterplot(x='review_scores_cleanliness', y='price', color="blue", data = f3_c)
sns.scatterplot(x='review_scores_cleanliness', y='Pred_cleanliness', color="red", data = f3_c)
# Out:
# <Axes: xlabel='review_scores_cleanliness', ylabel='price'>

# %%
sns.scatterplot(x='property_type', y='price', color="blue", data = f3_c)
sns.scatterplot(x='property_type', y='Pred_property', color="red", data = f3_c)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
coef_Deter_1= model_1.score(X=Vars_Indep1, y=Vars_Dep1)
coef_Deter_1
# Out:
# 0.0

# %%
coef_Deter_2= model_2.score(X=Vars_Indep2, y=Vars_Dep2)
coef_Deter_2
# Out:
# 0.016133671578424158

# %%
coef_Deter_3= model_3.score(X=Vars_Indep3, y=Vars_Dep3)
coef_Deter_3
# Out:
# 0.01307781073267611

# %%
coef_Deter_4= model_4.score(X=Vars_Indep4, y=Vars_Dep4)
coef_Deter_4
# Out:
# 0.10785742992723868

# %%
coef_Deter_5= model_5.score(X=Vars_Indep5, y=Vars_Dep5)
coef_Deter_5
# Out:
# 0.00401549094604936

# %%
coef_Deter_6= model_6.score(X=Vars_Indep6, y=Vars_Dep6)
coef_Deter_6
# Out:
# 0.005260903050239629

# %%
coef_Deter_7= model_7.score(X=Vars_Indep7, y=Vars_Dep7)
coef_Deter_7
# Out:
# 0.040584715154996065

# %%
coef_Deter_8= model_8.score(X=Vars_Indep8, y=Vars_Dep8)
coef_Deter_8
# Out:
# 0.01934539991907347

# %%
coef_Correl_1= np.sqrt(coef_Deter_1)
coef_Correl_1
# Out:
# np.float64(0.0)

# %%
coef_Correl_2= np.sqrt(coef_Deter_2)
coef_Correl_2
# Out:
# np.float64(0.1270183907094723)

# %%
coef_Correl_3= np.sqrt(coef_Deter_3)
coef_Correl_3
# Out:
# np.float64(0.11435825607570321)

# %%
coef_Correl_4= np.sqrt(coef_Deter_4)
coef_Correl_4
# Out:
# np.float64(0.32841654941132103)

# %%
coef_Correl_5= np.sqrt(coef_Deter_5)
coef_Correl_5
# Out:
# np.float64(0.06336790154367872)

# %%
coef_Correl_6= np.sqrt(coef_Deter_6)
coef_Correl_6
# Out:
# np.float64(0.0725320829029446)

# %%
coef_Correl_7= np.sqrt(coef_Deter_7)
coef_Correl_7
# Out:
# np.float64(0.20145648451960058)

# %%
coef_Correl_8= np.sqrt(coef_Deter_8)
coef_Correl_8
# Out:
# np.float64(0.13908774180017974)

# %%
df6 = f3.groupby(['room_type'])['room_type'].count()
df6
# Out:
# room_type
# 2    8693
# Name: room_type, dtype: int64

# %%
Corr_Factors=f3.corr()
Corr_Factors
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.218623
# host_is_superhost                NaN              0.218623           1.000000
# host_identity_verified           NaN             -0.118884           0.156201
# property_type                    NaN             -0.011407          -0.064265
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN              0.290606           0.038087
# accommodates                     NaN              0.068999          -0.003469
# bathrooms                        NaN             -0.043652          -0.007132
# price                            NaN              0.127018          -0.114358
# review_scores_cleanliness        NaN             -0.118973          -0.034997
#
#                            host_identity_verified  property_type  room_type  \
# Pred_room                                     NaN            NaN        NaN
# host_acceptance_rate                    -0.118884      -0.011407        NaN
# host_is_superhost                        0.156201      -0.064265        NaN
# host_identity_verified                   1.000000      -0.044328        NaN
# property_type                           -0.044328       1.000000        NaN
# room_type                                     NaN            NaN        NaN
# instant_bookable                         0.165735       0.035943        NaN
# accommodates                             0.043617       0.071528        NaN
# bathrooms                                0.068480      -0.080370        NaN
# price                                   -0.328417       0.139088        NaN
# review_scores_cleanliness               -0.138769       0.025390        NaN
#
#                            instant_bookable  accommodates  bathrooms  \
# Pred_room                               NaN           NaN        NaN
# host_acceptance_rate               0.290606      0.068999  -0.043652
# host_is_superhost                  0.038087     -0.003469  -0.007132
# host_identity_verified             0.165735      0.043617   0.068480
# property_type                      0.035943      0.071528  -0.080370
# room_type                               NaN           NaN        NaN
# instant_bookable                   1.000000      0.134485   0.013760
# accommodates                       0.134485      1.000000   0.072532
# bathrooms                          0.013760      0.072532   1.000000
# price                              0.063368      0.251809  -0.140783
# review_scores_cleanliness         -0.142607     -0.021409  -0.048854
#
#                               price  review_scores_cleanliness
# Pred_room                       NaN                        NaN
# host_acceptance_rate       0.127018                  -0.118973
# host_is_superhost         -0.114358                  -0.034997
# host_identity_verified    -0.328417                  -0.138769
# property_type              0.139088                   0.025390
# room_type                       NaN                        NaN
# instant_bookable           0.063368                  -0.142607
# accommodates               0.251809                  -0.021409
# bathrooms                 -0.140783                  -0.048854
# price                      1.000000                   0.201456
# review_scores_cleanliness  0.201456                   1.000000

# %%
Corr_Factors_pred=f3_c.corr()
Corr_Factors_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000          0.025390       -0.080370
# Pred_cleanliness                0.025390          1.000000       -0.048854
# Pred_bathrooms                 -0.080370         -0.048854        1.000000
# Pred_bookable                   0.035943         -0.142607        0.013760
# Pred_identity                   0.044328          0.138769       -0.068480
# Pred_superhost                  0.064265          0.034997        0.007132
# Pred_acceptance                -0.011407         -0.118973       -0.043652
# host_acceptance_rate           -0.011407         -0.118973       -0.043652
# host_is_superhost              -0.064265         -0.034997       -0.007132
# host_identity_verified         -0.044328         -0.138769        0.068480
# property_type                   1.000000          0.025390       -0.080370
# room_type                            NaN               NaN             NaN
# instant_bookable                0.035943         -0.142607        0.013760
# accommodates                    0.071528         -0.021409        0.072532
# bathrooms                      -0.080370         -0.048854        1.000000
# price                           0.139088          0.201456       -0.140783
# review_scores_cleanliness       0.025390          1.000000       -0.048854
#
#                            Pred_bookable  Pred_identity  Pred_superhost  \
# Pred_property                   0.035943       0.044328        0.064265
# Pred_cleanliness               -0.142607       0.138769        0.034997
# Pred_bathrooms                  0.013760      -0.068480        0.007132
# Pred_bookable                   1.000000      -0.165735       -0.038087
# Pred_identity                  -0.165735       1.000000        0.156201
# Pred_superhost                 -0.038087       0.156201        1.000000
# Pred_acceptance                 0.290606       0.118884       -0.218623
# host_acceptance_rate            0.290606       0.118884       -0.218623
# host_is_superhost               0.038087      -0.156201       -1.000000
# host_identity_verified          0.165735      -1.000000       -0.156201
# property_type                   0.035943       0.044328        0.064265
# room_type                            NaN            NaN             NaN
# instant_bookable                1.000000      -0.165735       -0.038087
# accommodates                    0.134485      -0.043617        0.003469
# bathrooms                       0.013760      -0.068480        0.007132
# price                           0.063368       0.328417        0.114358
# review_scores_cleanliness      -0.142607       0.138769        0.034997
#
#                            Pred_acceptance  host_acceptance_rate  \
# Pred_property                    -0.011407             -0.011407
# Pred_cleanliness                 -0.118973             -0.118973
# Pred_bathrooms                   -0.043652             -0.043652
# Pred_bookable                     0.290606              0.290606
# Pred_identity                     0.118884              0.118884
# Pred_superhost                   -0.218623             -0.218623
# Pred_acceptance                   1.000000              1.000000
# host_acceptance_rate              1.000000              1.000000
# host_is_superhost                 0.218623              0.218623
# host_identity_verified           -0.118884             -0.118884
# property_type                    -0.011407             -0.011407
# room_type                              NaN                   NaN
# instant_bookable                  0.290606              0.290606
# accommodates                      0.068999              0.068999
# bathrooms                        -0.043652             -0.043652
# price                             0.127018              0.127018
# review_scores_cleanliness        -0.118973             -0.118973
#
#                            host_is_superhost  host_identity_verified  \
# Pred_property                      -0.064265               -0.044328
# Pred_cleanliness                   -0.034997               -0.138769
# Pred_bathrooms                     -0.007132                0.068480
# Pred_bookable                       0.038087                0.165735
# Pred_identity                      -0.156201               -1.000000
# Pred_superhost                     -1.000000               -0.156201
# Pred_acceptance                     0.218623               -0.118884
# host_acceptance_rate                0.218623               -0.118884
# host_is_superhost                   1.000000                0.156201
# host_identity_verified              0.156201                1.000000
# property_type                      -0.064265               -0.044328
# room_type                                NaN                     NaN
# instant_bookable                    0.038087                0.165735
# accommodates                       -0.003469                0.043617
# bathrooms                          -0.007132                0.068480
# price                              -0.114358               -0.328417
# review_scores_cleanliness          -0.034997               -0.138769
#
#                            property_type  room_type  instant_bookable  \
# Pred_property                   1.000000        NaN          0.035943
# Pred_cleanliness                0.025390        NaN         -0.142607
# Pred_bathrooms                 -0.080370        NaN          0.013760
# Pred_bookable                   0.035943        NaN          1.000000
# Pred_identity                   0.044328        NaN         -0.165735
# Pred_superhost                  0.064265        NaN         -0.038087
# Pred_acceptance                -0.011407        NaN          0.290606
# host_acceptance_rate           -0.011407        NaN          0.290606
# host_is_superhost              -0.064265        NaN          0.038087
# host_identity_verified         -0.044328        NaN          0.165735
# property_type                   1.000000        NaN          0.035943
# room_type                            NaN        NaN               NaN
# instant_bookable                0.035943        NaN          1.000000
# accommodates                    0.071528        NaN          0.134485
# bathrooms                      -0.080370        NaN          0.013760
# price                           0.139088        NaN          0.063368
# review_scores_cleanliness       0.025390        NaN         -0.142607
#
#                            accommodates  bathrooms     price  \
# Pred_property                  0.071528  -0.080370  0.139088
# Pred_cleanliness              -0.021409  -0.048854  0.201456
# Pred_bathrooms                 0.072532   1.000000 -0.140783
# Pred_bookable                  0.134485   0.013760  0.063368
# Pred_identity                 -0.043617  -0.068480  0.328417
# Pred_superhost                 0.003469   0.007132  0.114358
# Pred_acceptance                0.068999  -0.043652  0.127018
# host_acceptance_rate           0.068999  -0.043652  0.127018
# host_is_superhost             -0.003469  -0.007132 -0.114358
# host_identity_verified         0.043617   0.068480 -0.328417
# property_type                  0.071528  -0.080370  0.139088
# room_type                           NaN        NaN       NaN
# instant_bookable               0.134485   0.013760  0.063368
# accommodates                   1.000000   0.072532  0.251809
# bathrooms                      0.072532   1.000000 -0.140783
# price                          0.251809  -0.140783  1.000000
# review_scores_cleanliness     -0.021409  -0.048854  0.201456
#
#                            review_scores_cleanliness
# Pred_property                               0.025390
# Pred_cleanliness                            1.000000
# Pred_bathrooms                             -0.048854
# Pred_bookable                              -0.142607
# Pred_identity                               0.138769
# Pred_superhost                              0.034997
# Pred_acceptance                            -0.118973
# host_acceptance_rate                       -0.118973
# host_is_superhost                          -0.034997
# host_identity_verified                     -0.138769
# property_type                               0.025390
# room_type                                        NaN
# instant_bookable                           -0.142607
# accommodates                               -0.021409
# bathrooms                                  -0.048854
# price                                       0.201456
# review_scores_cleanliness                   1.000000

# %%
Corr_Factors1=abs(Corr_Factors)
Corr_Factors1
# Out:
#                            Pred_room  host_acceptance_rate  host_is_superhost  \
# Pred_room                        NaN                   NaN                NaN
# host_acceptance_rate             NaN              1.000000           0.218623
# host_is_superhost                NaN              0.218623           1.000000
# host_identity_verified           NaN              0.118884           0.156201
# property_type                    NaN              0.011407           0.064265
# room_type                        NaN                   NaN                NaN
# instant_bookable                 NaN              0.290606           0.038087
# accommodates                     NaN              0.068999           0.003469
# bathrooms                        NaN              0.043652           0.007132
# price                            NaN              0.127018           0.114358
# review_scores_cleanliness        NaN              0.118973           0.034997
#
#                            host_identity_verified  property_type  room_type  \
# Pred_room                                     NaN            NaN        NaN
# host_acceptance_rate                     0.118884       0.011407        NaN
# host_is_superhost                        0.156201       0.064265        NaN
# host_identity_verified                   1.000000       0.044328        NaN
# property_type                            0.044328       1.000000        NaN
# room_type                                     NaN            NaN        NaN
# instant_bookable                         0.165735       0.035943        NaN
# accommodates                             0.043617       0.071528        NaN
# bathrooms                                0.068480       0.080370        NaN
# price                                    0.328417       0.139088        NaN
# review_scores_cleanliness                0.138769       0.025390        NaN
#
#                            instant_bookable  accommodates  bathrooms  \
# Pred_room                               NaN           NaN        NaN
# host_acceptance_rate               0.290606      0.068999   0.043652
# host_is_superhost                  0.038087      0.003469   0.007132
# host_identity_verified             0.165735      0.043617   0.068480
# property_type                      0.035943      0.071528   0.080370
# room_type                               NaN           NaN        NaN
# instant_bookable                   1.000000      0.134485   0.013760
# accommodates                       0.134485      1.000000   0.072532
# bathrooms                          0.013760      0.072532   1.000000
# price                              0.063368      0.251809   0.140783
# review_scores_cleanliness          0.142607      0.021409   0.048854
#
#                               price  review_scores_cleanliness
# Pred_room                       NaN                        NaN
# host_acceptance_rate       0.127018                   0.118973
# host_is_superhost          0.114358                   0.034997
# host_identity_verified     0.328417                   0.138769
# property_type              0.139088                   0.025390
# room_type                       NaN                        NaN
# instant_bookable           0.063368                   0.142607
# accommodates               0.251809                   0.021409
# bathrooms                  0.140783                   0.048854
# price                      1.000000                   0.201456
# review_scores_cleanliness  0.201456                   1.000000

# %%
Corr_Factors1_pred=abs(Corr_Factors_pred)
Corr_Factors1_pred
# Out:
#                            Pred_property  Pred_cleanliness  Pred_bathrooms  \
# Pred_property                   1.000000          0.025390        0.080370
# Pred_cleanliness                0.025390          1.000000        0.048854
# Pred_bathrooms                  0.080370          0.048854        1.000000
# Pred_bookable                   0.035943          0.142607        0.013760
# Pred_identity                   0.044328          0.138769        0.068480
# Pred_superhost                  0.064265          0.034997        0.007132
# Pred_acceptance                 0.011407          0.118973        0.043652
# host_acceptance_rate            0.011407          0.118973        0.043652
# host_is_superhost               0.064265          0.034997        0.007132
# host_identity_verified          0.044328          0.138769        0.068480
# property_type                   1.000000          0.025390        0.080370
# room_type                            NaN               NaN             NaN
# instant_bookable                0.035943          0.142607        0.013760
# accommodates                    0.071528          0.021409        0.072532
# bathrooms                       0.080370          0.048854        1.000000
# price                           0.139088          0.201456        0.140783
# review_scores_cleanliness       0.025390          1.000000        0.048854
#
#                            Pred_bookable  Pred_identity  Pred_superhost  \
# Pred_property                   0.035943       0.044328        0.064265
# Pred_cleanliness                0.142607       0.138769        0.034997
# Pred_bathrooms                  0.013760       0.068480        0.007132
# Pred_bookable                   1.000000       0.165735        0.038087
# Pred_identity                   0.165735       1.000000        0.156201
# Pred_superhost                  0.038087       0.156201        1.000000
# Pred_acceptance                 0.290606       0.118884        0.218623
# host_acceptance_rate            0.290606       0.118884        0.218623
# host_is_superhost               0.038087       0.156201        1.000000
# host_identity_verified          0.165735       1.000000        0.156201
# property_type                   0.035943       0.044328        0.064265
# room_type                            NaN            NaN             NaN
# instant_bookable                1.000000       0.165735        0.038087
# accommodates                    0.134485       0.043617        0.003469
# bathrooms                       0.013760       0.068480        0.007132
# price                           0.063368       0.328417        0.114358
# review_scores_cleanliness       0.142607       0.138769        0.034997
#
#                            Pred_acceptance  host_acceptance_rate  \
# Pred_property                     0.011407              0.011407
# Pred_cleanliness                  0.118973              0.118973
# Pred_bathrooms                    0.043652              0.043652
# Pred_bookable                     0.290606              0.290606
# Pred_identity                     0.118884              0.118884
# Pred_superhost                    0.218623              0.218623
# Pred_acceptance                   1.000000              1.000000
# host_acceptance_rate              1.000000              1.000000
# host_is_superhost                 0.218623              0.218623
# host_identity_verified            0.118884              0.118884
# property_type                     0.011407              0.011407
# room_type                              NaN                   NaN
# instant_bookable                  0.290606              0.290606
# accommodates                      0.068999              0.068999
# bathrooms                         0.043652              0.043652
# price                             0.127018              0.127018
# review_scores_cleanliness         0.118973              0.118973
#
#                            host_is_superhost  host_identity_verified  \
# Pred_property                       0.064265                0.044328
# Pred_cleanliness                    0.034997                0.138769
# Pred_bathrooms                      0.007132                0.068480
# Pred_bookable                       0.038087                0.165735
# Pred_identity                       0.156201                1.000000
# Pred_superhost                      1.000000                0.156201
# Pred_acceptance                     0.218623                0.118884
# host_acceptance_rate                0.218623                0.118884
# host_is_superhost                   1.000000                0.156201
# host_identity_verified              0.156201                1.000000
# property_type                       0.064265                0.044328
# room_type                                NaN                     NaN
# instant_bookable                    0.038087                0.165735
# accommodates                        0.003469                0.043617
# bathrooms                           0.007132                0.068480
# price                               0.114358                0.328417
# review_scores_cleanliness           0.034997                0.138769
#
#                            property_type  room_type  instant_bookable  \
# Pred_property                   1.000000        NaN          0.035943
# Pred_cleanliness                0.025390        NaN          0.142607
# Pred_bathrooms                  0.080370        NaN          0.013760
# Pred_bookable                   0.035943        NaN          1.000000
# Pred_identity                   0.044328        NaN          0.165735
# Pred_superhost                  0.064265        NaN          0.038087
# Pred_acceptance                 0.011407        NaN          0.290606
# host_acceptance_rate            0.011407        NaN          0.290606
# host_is_superhost               0.064265        NaN          0.038087
# host_identity_verified          0.044328        NaN          0.165735
# property_type                   1.000000        NaN          0.035943
# room_type                            NaN        NaN               NaN
# instant_bookable                0.035943        NaN          1.000000
# accommodates                    0.071528        NaN          0.134485
# bathrooms                       0.080370        NaN          0.013760
# price                           0.139088        NaN          0.063368
# review_scores_cleanliness       0.025390        NaN          0.142607
#
#                            accommodates  bathrooms     price  \
# Pred_property                  0.071528   0.080370  0.139088
# Pred_cleanliness               0.021409   0.048854  0.201456
# Pred_bathrooms                 0.072532   1.000000  0.140783
# Pred_bookable                  0.134485   0.013760  0.063368
# Pred_identity                  0.043617   0.068480  0.328417
# Pred_superhost                 0.003469   0.007132  0.114358
# Pred_acceptance                0.068999   0.043652  0.127018
# host_acceptance_rate           0.068999   0.043652  0.127018
# host_is_superhost              0.003469   0.007132  0.114358
# host_identity_verified         0.043617   0.068480  0.328417
# property_type                  0.071528   0.080370  0.139088
# room_type                           NaN        NaN       NaN
# instant_bookable               0.134485   0.013760  0.063368
# accommodates                   1.000000   0.072532  0.251809
# bathrooms                      0.072532   1.000000  0.140783
# price                          0.251809   0.140783  1.000000
# review_scores_cleanliness      0.021409   0.048854  0.201456
#
#                            review_scores_cleanliness
# Pred_property                               0.025390
# Pred_cleanliness                            1.000000
# Pred_bathrooms                              0.048854
# Pred_bookable                               0.142607
# Pred_identity                               0.138769
# Pred_superhost                              0.034997
# Pred_acceptance                             0.118973
# host_acceptance_rate                        0.118973
# host_is_superhost                           0.034997
# host_identity_verified                      0.138769
# property_type                               0.025390
# room_type                                        NaN
# instant_bookable                            0.142607
# accommodates                                0.021409
# bathrooms                                   0.048854
# price                                       0.201456
# review_scores_cleanliness                   1.000000

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,12))
Heart_Nap = sns.heatmap(Corr_Factors1_pred, cmap= 'Purples', annot=True, fmt=".2f")
Heart_Nap
# Out:
# <Axes: >
